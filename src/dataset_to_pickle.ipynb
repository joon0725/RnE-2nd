# %%
import pickle

import numpy as np
import os 
import os.path

from dev.preprocessing import faceMesh_video
from dev.preprocessing import handPose_video
from dev.preprocessing import points_to_displacement

# %%
points_num = [0, 7, 10, 13, 14, 17, 21, 33, 37, 39, 40, 46, 52, 53, 54, 55, 58, 61, 63, 65, 66, 67, 70, 78, 80, 81, 82, 84, 87, 88, 91, 93, 95, 103, 105, 107, 109, 127, 132, 133, 136, 144, 145, 146, 148, 149, 150, 152, 153, 154, 155, 157, 158, 159, 160, 161, 162, 163, 172, 173, 176, 178, 181, 185, 191, 234, 246, 249, 251, 263, 267, 269, 270, 276, 282, 283, 284, 285, 288, 291, 293, 295, 296, 297, 300, 308, 310, 311, 312, 314, 317, 318, 321, 323, 324, 332, 334, 336, 338, 356, 361, 362, 365, 373, 374, 375, 377, 378, 379, 380, 381, 382, 384, 385, 386, 387, 388, 389, 390, 397, 398, 400, 402, 405, 409, 415, 454, 466]
len(points_num)
# Out:
# 128

# %%
with open('../dataset/processed/KSL_handpose_and_facemesh.p', 'wb') as file:
    dataset_pickle = []

    face_count = 128
    hand_count = 21
    for i in range(1, 78):
        for j in range(20):
            if (j == 18 or j==17 or not os.path.isfile(f"../dataset/{str(i).zfill(2)}/{str(j).zfill(2)}_{str(i).zfill(2)}.MP4")):
                print(f'{i}번째 단어의 {j}번째 영상, {str(j).zfill(2)}_{str(i).zfill(2)}.MP4 는 존재하지 않습니다. Skipping...')
                continue
            print(f'{i}번째 단어의 {j}번째 영상, {str(j).zfill(2)}_{str(i).zfill(2)}.MP4 처리 시작.')

            face_points = faceMesh_video(i, j)
            hand_points = handPose_video(i, j)
            
            point_displacements = [] # 모든 점에 대한 변위 데이터 저장
            
            # 한 영상에서의 변위데이터 딕셔너리 배열 가져옴
            displacement = points_to_displacement(face_points, face_count, hand_points, hand_count)

            for per_frame_data in displacement:
                temp = np.concatenate([per_frame_data['face'], per_frame_data['hands']['left'], per_frame_data['hands']['right']], axis=0)
                point_displacements.append(temp)
            
            point_displacements = np.array(point_displacements)

            video_data = [point_displacements, i]

            dataset_pickle.append(video_data)
            print(f'{i}번째 단어의 {j}번째 영상, {str(j).zfill(2)}_{str(i).zfill(2)}.MP4 처리 완료.')
            print()

    pickle.dump(dataset_pickle, file)
# Out:
# 1번째 단어의 0번째 영상, 00_01.MP4 처리 시작.
# 1번째 단어의 0번째 영상, 00_01.MP4 처리 완료.
#
# 1번째 단어의 1번째 영상, 01_01.MP4 처리 시작.
# 1번째 단어의 1번째 영상, 01_01.MP4 처리 완료.
#
# 1번째 단어의 2번째 영상, 02_01.MP4 처리 시작.
# 1번째 단어의 2번째 영상, 02_01.MP4 처리 완료.
#
# 1번째 단어의 3번째 영상, 03_01.MP4 처리 시작.
# 1번째 단어의 3번째 영상, 03_01.MP4 처리 완료.
#
# 1번째 단어의 4번째 영상, 04_01.MP4 처리 시작.
# 1번째 단어의 4번째 영상, 04_01.MP4 처리 완료.
#
# 1번째 단어의 5번째 영상, 05_01.MP4 처리 시작.
# 1번째 단어의 5번째 영상, 05_01.MP4 처리 완료.
#
# 1번째 단어의 6번째 영상, 06_01.MP4 처리 시작.
# 1번째 단어의 6번째 영상, 06_01.MP4 처리 완료.
#
# 1번째 단어의 7번째 영상, 07_01.MP4 처리 시작.
# 1번째 단어의 7번째 영상, 07_01.MP4 처리 완료.
#
# 1번째 단어의 8번째 영상, 08_01.MP4 처리 시작.
# 1번째 단어의 8번째 영상, 08_01.MP4 처리 완료.
#
# 1번째 단어의 9번째 영상, 09_01.MP4 처리 시작.
# 1번째 단어의 9번째 영상, 09_01.MP4 처리 완료.
#
# 1번째 단어의 10번째 영상, 10_01.MP4 처리 시작.
# 1번째 단어의 10번째 영상, 10_01.MP4 처리 완료.
#
# 1번째 단어의 11번째 영상, 11_01.MP4 처리 시작.
# 1번째 단어의 11번째 영상, 11_01.MP4 처리 완료.
#
# 1번째 단어의 12번째 영상, 12_01.MP4 처리 시작.
# 1번째 단어의 12번째 영상, 12_01.MP4 처리 완료.
#
# 1번째 단어의 13번째 영상, 13_01.MP4 처리 시작.
# 1번째 단어의 13번째 영상, 13_01.MP4 처리 완료.
#
# 1번째 단어의 14번째 영상, 14_01.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 1번째 단어의 14번째 영상, 14_01.MP4 처리 완료.
#
# 1번째 단어의 15번째 영상, 15_01.MP4 처리 시작.
# 1번째 단어의 15번째 영상, 15_01.MP4 처리 완료.
#
# 1번째 단어의 16번째 영상, 16_01.MP4 처리 시작.
# 1번째 단어의 16번째 영상, 16_01.MP4 처리 완료.
#
# 1번째 단어의 17번째 영상, 17_01.MP4 는 존재하지 않습니다. Skipping...
# 1번째 단어의 18번째 영상, 18_01.MP4 는 존재하지 않습니다. Skipping...
# 1번째 단어의 19번째 영상, 19_01.MP4 처리 시작.
# 1번째 단어의 19번째 영상, 19_01.MP4 처리 완료.
#
# 2번째 단어의 0번째 영상, 00_02.MP4 처리 시작.
# 2번째 단어의 0번째 영상, 00_02.MP4 처리 완료.
#
# 2번째 단어의 1번째 영상, 01_02.MP4 처리 시작.
# 2번째 단어의 1번째 영상, 01_02.MP4 처리 완료.
#
# 2번째 단어의 2번째 영상, 02_02.MP4 처리 시작.
# 2번째 단어의 2번째 영상, 02_02.MP4 처리 완료.
#
# 2번째 단어의 3번째 영상, 03_02.MP4 처리 시작.
# 2번째 단어의 3번째 영상, 03_02.MP4 처리 완료.
#
# 2번째 단어의 4번째 영상, 04_02.MP4 처리 시작.
# 2번째 단어의 4번째 영상, 04_02.MP4 처리 완료.
#
# 2번째 단어의 5번째 영상, 05_02.MP4 처리 시작.
# 2번째 단어의 5번째 영상, 05_02.MP4 처리 완료.
#
# 2번째 단어의 6번째 영상, 06_02.MP4 처리 시작.
# 2번째 단어의 6번째 영상, 06_02.MP4 처리 완료.
#
# 2번째 단어의 7번째 영상, 07_02.MP4 처리 시작.
# 2번째 단어의 7번째 영상, 07_02.MP4 처리 완료.
#
# 2번째 단어의 8번째 영상, 08_02.MP4 처리 시작.
# 2번째 단어의 8번째 영상, 08_02.MP4 처리 완료.
#
# 2번째 단어의 9번째 영상, 09_02.MP4 처리 시작.
# 2번째 단어의 9번째 영상, 09_02.MP4 처리 완료.
#
# 2번째 단어의 10번째 영상, 10_02.MP4 처리 시작.
# 2번째 단어의 10번째 영상, 10_02.MP4 처리 완료.
#
# 2번째 단어의 11번째 영상, 11_02.MP4 처리 시작.
# 2번째 단어의 11번째 영상, 11_02.MP4 처리 완료.
#
# 2번째 단어의 12번째 영상, 12_02.MP4 처리 시작.
# 2번째 단어의 12번째 영상, 12_02.MP4 처리 완료.
#
# 2번째 단어의 13번째 영상, 13_02.MP4 처리 시작.
# 2번째 단어의 13번째 영상, 13_02.MP4 처리 완료.
#
# 2번째 단어의 14번째 영상, 14_02.MP4 처리 시작.
# 2번째 단어의 14번째 영상, 14_02.MP4 처리 완료.
#
# 2번째 단어의 15번째 영상, 15_02.MP4 처리 시작.
# 2번째 단어의 15번째 영상, 15_02.MP4 처리 완료.
#
# 2번째 단어의 16번째 영상, 16_02.MP4 처리 시작.
# 2번째 단어의 16번째 영상, 16_02.MP4 처리 완료.
#
# 2번째 단어의 17번째 영상, 17_02.MP4 는 존재하지 않습니다. Skipping...
# 2번째 단어의 18번째 영상, 18_02.MP4 는 존재하지 않습니다. Skipping...
# 2번째 단어의 19번째 영상, 19_02.MP4 처리 시작.
# 2번째 단어의 19번째 영상, 19_02.MP4 처리 완료.
#
# 3번째 단어의 0번째 영상, 00_03.MP4 처리 시작.
# 3번째 단어의 0번째 영상, 00_03.MP4 처리 완료.
#
# 3번째 단어의 1번째 영상, 01_03.MP4 처리 시작.
# 3번째 단어의 1번째 영상, 01_03.MP4 처리 완료.
#
# 3번째 단어의 2번째 영상, 02_03.MP4 처리 시작.
# 3번째 단어의 2번째 영상, 02_03.MP4 처리 완료.
#
# 3번째 단어의 3번째 영상, 03_03.MP4 처리 시작.
# 3번째 단어의 3번째 영상, 03_03.MP4 처리 완료.
#
# 3번째 단어의 4번째 영상, 04_03.MP4 처리 시작.
# 3번째 단어의 4번째 영상, 04_03.MP4 처리 완료.
#
# 3번째 단어의 5번째 영상, 05_03.MP4 처리 시작.
# 3번째 단어의 5번째 영상, 05_03.MP4 처리 완료.
#
# 3번째 단어의 6번째 영상, 06_03.MP4 처리 시작.
# 3번째 단어의 6번째 영상, 06_03.MP4 처리 완료.
#
# 3번째 단어의 7번째 영상, 07_03.MP4 처리 시작.
# 3번째 단어의 7번째 영상, 07_03.MP4 처리 완료.
#
# 3번째 단어의 8번째 영상, 08_03.MP4 처리 시작.
# 3번째 단어의 8번째 영상, 08_03.MP4 처리 완료.
#
# 3번째 단어의 9번째 영상, 09_03.MP4 처리 시작.
# 3번째 단어의 9번째 영상, 09_03.MP4 처리 완료.
#
# 3번째 단어의 10번째 영상, 10_03.MP4 처리 시작.
# 3번째 단어의 10번째 영상, 10_03.MP4 처리 완료.
#
# 3번째 단어의 11번째 영상, 11_03.MP4 처리 시작.
# 3번째 단어의 11번째 영상, 11_03.MP4 처리 완료.
#
# 3번째 단어의 12번째 영상, 12_03.MP4 처리 시작.
# 3번째 단어의 12번째 영상, 12_03.MP4 처리 완료.
#
# 3번째 단어의 13번째 영상, 13_03.MP4 처리 시작.
# 3번째 단어의 13번째 영상, 13_03.MP4 처리 완료.
#
# 3번째 단어의 14번째 영상, 14_03.MP4 처리 시작.
# 3번째 단어의 14번째 영상, 14_03.MP4 처리 완료.
#
# 3번째 단어의 15번째 영상, 15_03.MP4 처리 시작.
# 3번째 단어의 15번째 영상, 15_03.MP4 처리 완료.
#
# 3번째 단어의 16번째 영상, 16_03.MP4 처리 시작.
# 3번째 단어의 16번째 영상, 16_03.MP4 처리 완료.
#
# 3번째 단어의 17번째 영상, 17_03.MP4 는 존재하지 않습니다. Skipping...
# 3번째 단어의 18번째 영상, 18_03.MP4 는 존재하지 않습니다. Skipping...
# 3번째 단어의 19번째 영상, 19_03.MP4 처리 시작.
# 3번째 단어의 19번째 영상, 19_03.MP4 처리 완료.
#
# 4번째 단어의 0번째 영상, 00_04.MP4 처리 시작.
# 4번째 단어의 0번째 영상, 00_04.MP4 처리 완료.
#
# 4번째 단어의 1번째 영상, 01_04.MP4 처리 시작.
# 4번째 단어의 1번째 영상, 01_04.MP4 처리 완료.
#
# 4번째 단어의 2번째 영상, 02_04.MP4 처리 시작.
# 4번째 단어의 2번째 영상, 02_04.MP4 처리 완료.
#
# 4번째 단어의 3번째 영상, 03_04.MP4 처리 시작.
# 4번째 단어의 3번째 영상, 03_04.MP4 처리 완료.
#
# 4번째 단어의 4번째 영상, 04_04.MP4 처리 시작.
# 4번째 단어의 4번째 영상, 04_04.MP4 처리 완료.
#
# 4번째 단어의 5번째 영상, 05_04.MP4 처리 시작.
# 4번째 단어의 5번째 영상, 05_04.MP4 처리 완료.
#
# 4번째 단어의 6번째 영상, 06_04.MP4 처리 시작.
# 4번째 단어의 6번째 영상, 06_04.MP4 처리 완료.
#
# 4번째 단어의 7번째 영상, 07_04.MP4 처리 시작.
# 4번째 단어의 7번째 영상, 07_04.MP4 처리 완료.
#
# 4번째 단어의 8번째 영상, 08_04.MP4 처리 시작.
# 4번째 단어의 8번째 영상, 08_04.MP4 처리 완료.
#
# 4번째 단어의 9번째 영상, 09_04.MP4 처리 시작.
# 4번째 단어의 9번째 영상, 09_04.MP4 처리 완료.
#
# 4번째 단어의 10번째 영상, 10_04.MP4 처리 시작.
# 4번째 단어의 10번째 영상, 10_04.MP4 처리 완료.
#
# 4번째 단어의 11번째 영상, 11_04.MP4 처리 시작.
# 4번째 단어의 11번째 영상, 11_04.MP4 처리 완료.
#
# 4번째 단어의 12번째 영상, 12_04.MP4 처리 시작.
# 4번째 단어의 12번째 영상, 12_04.MP4 처리 완료.
#
# 4번째 단어의 13번째 영상, 13_04.MP4 처리 시작.
# 4번째 단어의 13번째 영상, 13_04.MP4 처리 완료.
#
# 4번째 단어의 14번째 영상, 14_04.MP4 처리 시작.
# 4번째 단어의 14번째 영상, 14_04.MP4 처리 완료.
#
# 4번째 단어의 15번째 영상, 15_04.MP4 처리 시작.
# 4번째 단어의 15번째 영상, 15_04.MP4 처리 완료.
#
# 4번째 단어의 16번째 영상, 16_04.MP4 처리 시작.
# 4번째 단어의 16번째 영상, 16_04.MP4 처리 완료.
#
# 4번째 단어의 17번째 영상, 17_04.MP4 는 존재하지 않습니다. Skipping...
# 4번째 단어의 18번째 영상, 18_04.MP4 는 존재하지 않습니다. Skipping...
# 4번째 단어의 19번째 영상, 19_04.MP4 처리 시작.
# 4번째 단어의 19번째 영상, 19_04.MP4 처리 완료.
#
# 5번째 단어의 0번째 영상, 00_05.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 5번째 단어의 0번째 영상, 00_05.MP4 처리 완료.
#
# 5번째 단어의 1번째 영상, 01_05.MP4 처리 시작.
# 5번째 단어의 1번째 영상, 01_05.MP4 처리 완료.
#
# 5번째 단어의 2번째 영상, 02_05.MP4 처리 시작.
# 5번째 단어의 2번째 영상, 02_05.MP4 처리 완료.
#
# 5번째 단어의 3번째 영상, 03_05.MP4 처리 시작.
# 5번째 단어의 3번째 영상, 03_05.MP4 처리 완료.
#
# 5번째 단어의 4번째 영상, 04_05.MP4 처리 시작.
# 5번째 단어의 4번째 영상, 04_05.MP4 처리 완료.
#
# 5번째 단어의 5번째 영상, 05_05.MP4 처리 시작.
# 5번째 단어의 5번째 영상, 05_05.MP4 처리 완료.
#
# 5번째 단어의 6번째 영상, 06_05.MP4 처리 시작.
# 5번째 단어의 6번째 영상, 06_05.MP4 처리 완료.
#
# 5번째 단어의 7번째 영상, 07_05.MP4 처리 시작.
# 5번째 단어의 7번째 영상, 07_05.MP4 처리 완료.
#
# 5번째 단어의 8번째 영상, 08_05.MP4 처리 시작.
# 5번째 단어의 8번째 영상, 08_05.MP4 처리 완료.
#
# 5번째 단어의 9번째 영상, 09_05.MP4 처리 시작.
# 5번째 단어의 9번째 영상, 09_05.MP4 처리 완료.
#
# 5번째 단어의 10번째 영상, 10_05.MP4 처리 시작.
# 5번째 단어의 10번째 영상, 10_05.MP4 처리 완료.
#
# 5번째 단어의 11번째 영상, 11_05.MP4 처리 시작.
# 5번째 단어의 11번째 영상, 11_05.MP4 처리 완료.
#
# 5번째 단어의 12번째 영상, 12_05.MP4 처리 시작.
# 5번째 단어의 12번째 영상, 12_05.MP4 처리 완료.
#
# 5번째 단어의 13번째 영상, 13_05.MP4 처리 시작.
# 5번째 단어의 13번째 영상, 13_05.MP4 처리 완료.
#
# 5번째 단어의 14번째 영상, 14_05.MP4 는 존재하지 않습니다. Skipping...
# 5번째 단어의 15번째 영상, 15_05.MP4 처리 시작.
# 5번째 단어의 15번째 영상, 15_05.MP4 처리 완료.
#
# 5번째 단어의 16번째 영상, 16_05.MP4 처리 시작.
# 5번째 단어의 16번째 영상, 16_05.MP4 처리 완료.
#
# 5번째 단어의 17번째 영상, 17_05.MP4 는 존재하지 않습니다. Skipping...
# 5번째 단어의 18번째 영상, 18_05.MP4 는 존재하지 않습니다. Skipping...
# 5번째 단어의 19번째 영상, 19_05.MP4 처리 시작.
# 5번째 단어의 19번째 영상, 19_05.MP4 처리 완료.
#
# 6번째 단어의 0번째 영상, 00_06.MP4 처리 시작.
# 인식 안됨
# 6번째 단어의 0번째 영상, 00_06.MP4 처리 완료.
#
# 6번째 단어의 1번째 영상, 01_06.MP4 처리 시작.
# 6번째 단어의 1번째 영상, 01_06.MP4 처리 완료.
#
# 6번째 단어의 2번째 영상, 02_06.MP4 처리 시작.
# 6번째 단어의 2번째 영상, 02_06.MP4 처리 완료.
#
# 6번째 단어의 3번째 영상, 03_06.MP4 처리 시작.
# 6번째 단어의 3번째 영상, 03_06.MP4 처리 완료.
#
# 6번째 단어의 4번째 영상, 04_06.MP4 처리 시작.
# 6번째 단어의 4번째 영상, 04_06.MP4 처리 완료.
#
# 6번째 단어의 5번째 영상, 05_06.MP4 처리 시작.
# 6번째 단어의 5번째 영상, 05_06.MP4 처리 완료.
#
# 6번째 단어의 6번째 영상, 06_06.MP4 는 존재하지 않습니다. Skipping...
# 6번째 단어의 7번째 영상, 07_06.MP4 처리 시작.
# 6번째 단어의 7번째 영상, 07_06.MP4 처리 완료.
#
# 6번째 단어의 8번째 영상, 08_06.MP4 처리 시작.
# 6번째 단어의 8번째 영상, 08_06.MP4 처리 완료.
#
# 6번째 단어의 9번째 영상, 09_06.MP4 처리 시작.
# 6번째 단어의 9번째 영상, 09_06.MP4 처리 완료.
#
# 6번째 단어의 10번째 영상, 10_06.MP4 처리 시작.
# 6번째 단어의 10번째 영상, 10_06.MP4 처리 완료.
#
# 6번째 단어의 11번째 영상, 11_06.MP4 처리 시작.
# 6번째 단어의 11번째 영상, 11_06.MP4 처리 완료.
#
# 6번째 단어의 12번째 영상, 12_06.MP4 처리 시작.
# 6번째 단어의 12번째 영상, 12_06.MP4 처리 완료.
#
# 6번째 단어의 13번째 영상, 13_06.MP4 처리 시작.
# 6번째 단어의 13번째 영상, 13_06.MP4 처리 완료.
#
# 6번째 단어의 14번째 영상, 14_06.MP4 처리 시작.
# 6번째 단어의 14번째 영상, 14_06.MP4 처리 완료.
#
# 6번째 단어의 15번째 영상, 15_06.MP4 처리 시작.
# 6번째 단어의 15번째 영상, 15_06.MP4 처리 완료.
#
# 6번째 단어의 16번째 영상, 16_06.MP4 처리 시작.
# 6번째 단어의 16번째 영상, 16_06.MP4 처리 완료.
#
# 6번째 단어의 17번째 영상, 17_06.MP4 는 존재하지 않습니다. Skipping...
# 6번째 단어의 18번째 영상, 18_06.MP4 는 존재하지 않습니다. Skipping...
# 6번째 단어의 19번째 영상, 19_06.MP4 처리 시작.
# 6번째 단어의 19번째 영상, 19_06.MP4 처리 완료.
#
# 7번째 단어의 0번째 영상, 00_07.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 7번째 단어의 0번째 영상, 00_07.MP4 처리 완료.
#
# 7번째 단어의 1번째 영상, 01_07.MP4 처리 시작.
# 7번째 단어의 1번째 영상, 01_07.MP4 처리 완료.
#
# 7번째 단어의 2번째 영상, 02_07.MP4 처리 시작.
# 7번째 단어의 2번째 영상, 02_07.MP4 처리 완료.
#
# 7번째 단어의 3번째 영상, 03_07.MP4 처리 시작.
# 7번째 단어의 3번째 영상, 03_07.MP4 처리 완료.
#
# 7번째 단어의 4번째 영상, 04_07.MP4 처리 시작.
# 7번째 단어의 4번째 영상, 04_07.MP4 처리 완료.
#
# 7번째 단어의 5번째 영상, 05_07.MP4 처리 시작.
# 7번째 단어의 5번째 영상, 05_07.MP4 처리 완료.
#
# 7번째 단어의 6번째 영상, 06_07.MP4 는 존재하지 않습니다. Skipping...
# 7번째 단어의 7번째 영상, 07_07.MP4 처리 시작.
# 7번째 단어의 7번째 영상, 07_07.MP4 처리 완료.
#
# 7번째 단어의 8번째 영상, 08_07.MP4 처리 시작.
# 7번째 단어의 8번째 영상, 08_07.MP4 처리 완료.
#
# 7번째 단어의 9번째 영상, 09_07.MP4 처리 시작.
# 7번째 단어의 9번째 영상, 09_07.MP4 처리 완료.
#
# 7번째 단어의 10번째 영상, 10_07.MP4 처리 시작.
# 7번째 단어의 10번째 영상, 10_07.MP4 처리 완료.
#
# 7번째 단어의 11번째 영상, 11_07.MP4 처리 시작.
# 7번째 단어의 11번째 영상, 11_07.MP4 처리 완료.
#
# 7번째 단어의 12번째 영상, 12_07.MP4 처리 시작.
# 7번째 단어의 12번째 영상, 12_07.MP4 처리 완료.
#
# 7번째 단어의 13번째 영상, 13_07.MP4 처리 시작.
# 7번째 단어의 13번째 영상, 13_07.MP4 처리 완료.
#
# 7번째 단어의 14번째 영상, 14_07.MP4 처리 시작.
# 7번째 단어의 14번째 영상, 14_07.MP4 처리 완료.
#
# 7번째 단어의 15번째 영상, 15_07.MP4 처리 시작.
# 7번째 단어의 15번째 영상, 15_07.MP4 처리 완료.
#
# 7번째 단어의 16번째 영상, 16_07.MP4 처리 시작.
# 7번째 단어의 16번째 영상, 16_07.MP4 처리 완료.
#
# 7번째 단어의 17번째 영상, 17_07.MP4 는 존재하지 않습니다. Skipping...
# 7번째 단어의 18번째 영상, 18_07.MP4 는 존재하지 않습니다. Skipping...
# 7번째 단어의 19번째 영상, 19_07.MP4 처리 시작.
# 7번째 단어의 19번째 영상, 19_07.MP4 처리 완료.
#
# 8번째 단어의 0번째 영상, 00_08.MP4 처리 시작.
# 8번째 단어의 0번째 영상, 00_08.MP4 처리 완료.
#
# 8번째 단어의 1번째 영상, 01_08.MP4 처리 시작.
# 8번째 단어의 1번째 영상, 01_08.MP4 처리 완료.
#
# 8번째 단어의 2번째 영상, 02_08.MP4 처리 시작.
# 8번째 단어의 2번째 영상, 02_08.MP4 처리 완료.
#
# 8번째 단어의 3번째 영상, 03_08.MP4 처리 시작.
# 8번째 단어의 3번째 영상, 03_08.MP4 처리 완료.
#
# 8번째 단어의 4번째 영상, 04_08.MP4 처리 시작.
# 8번째 단어의 4번째 영상, 04_08.MP4 처리 완료.
#
# 8번째 단어의 5번째 영상, 05_08.MP4 처리 시작.
# 8번째 단어의 5번째 영상, 05_08.MP4 처리 완료.
#
# 8번째 단어의 6번째 영상, 06_08.MP4 처리 시작.
# 8번째 단어의 6번째 영상, 06_08.MP4 처리 완료.
#
# 8번째 단어의 7번째 영상, 07_08.MP4 처리 시작.
# 8번째 단어의 7번째 영상, 07_08.MP4 처리 완료.
#
# 8번째 단어의 8번째 영상, 08_08.MP4 는 존재하지 않습니다. Skipping...
# 8번째 단어의 9번째 영상, 09_08.MP4 처리 시작.
# 8번째 단어의 9번째 영상, 09_08.MP4 처리 완료.
#
# 8번째 단어의 10번째 영상, 10_08.MP4 처리 시작.
# 8번째 단어의 10번째 영상, 10_08.MP4 처리 완료.
#
# 8번째 단어의 11번째 영상, 11_08.MP4 처리 시작.
# 8번째 단어의 11번째 영상, 11_08.MP4 처리 완료.
#
# 8번째 단어의 12번째 영상, 12_08.MP4 처리 시작.
# 8번째 단어의 12번째 영상, 12_08.MP4 처리 완료.
#
# 8번째 단어의 13번째 영상, 13_08.MP4 처리 시작.
# 8번째 단어의 13번째 영상, 13_08.MP4 처리 완료.
#
# 8번째 단어의 14번째 영상, 14_08.MP4 처리 시작.
# 8번째 단어의 14번째 영상, 14_08.MP4 처리 완료.
#
# 8번째 단어의 15번째 영상, 15_08.MP4 처리 시작.
# 8번째 단어의 15번째 영상, 15_08.MP4 처리 완료.
#
# 8번째 단어의 16번째 영상, 16_08.MP4 처리 시작.
# 8번째 단어의 16번째 영상, 16_08.MP4 처리 완료.
#
# 8번째 단어의 17번째 영상, 17_08.MP4 는 존재하지 않습니다. Skipping...
# 8번째 단어의 18번째 영상, 18_08.MP4 는 존재하지 않습니다. Skipping...
# 8번째 단어의 19번째 영상, 19_08.MP4 처리 시작.
# 8번째 단어의 19번째 영상, 19_08.MP4 처리 완료.
#
# 9번째 단어의 0번째 영상, 00_09.MP4 처리 시작.
# 인식 안됨
# 9번째 단어의 0번째 영상, 00_09.MP4 처리 완료.
#
# 9번째 단어의 1번째 영상, 01_09.MP4 처리 시작.
# 9번째 단어의 1번째 영상, 01_09.MP4 처리 완료.
#
# 9번째 단어의 2번째 영상, 02_09.MP4 처리 시작.
# 9번째 단어의 2번째 영상, 02_09.MP4 처리 완료.
#
# 9번째 단어의 3번째 영상, 03_09.MP4 처리 시작.
# 9번째 단어의 3번째 영상, 03_09.MP4 처리 완료.
#
# 9번째 단어의 4번째 영상, 04_09.MP4 처리 시작.
# 9번째 단어의 4번째 영상, 04_09.MP4 처리 완료.
#
# 9번째 단어의 5번째 영상, 05_09.MP4 처리 시작.
# 9번째 단어의 5번째 영상, 05_09.MP4 처리 완료.
#
# 9번째 단어의 6번째 영상, 06_09.MP4 는 존재하지 않습니다. Skipping...
# 9번째 단어의 7번째 영상, 07_09.MP4 처리 시작.
# 9번째 단어의 7번째 영상, 07_09.MP4 처리 완료.
#
# 9번째 단어의 8번째 영상, 08_09.MP4 처리 시작.
# 9번째 단어의 8번째 영상, 08_09.MP4 처리 완료.
#
# 9번째 단어의 9번째 영상, 09_09.MP4 처리 시작.
# 9번째 단어의 9번째 영상, 09_09.MP4 처리 완료.
#
# 9번째 단어의 10번째 영상, 10_09.MP4 처리 시작.
# 9번째 단어의 10번째 영상, 10_09.MP4 처리 완료.
#
# 9번째 단어의 11번째 영상, 11_09.MP4 처리 시작.
# 9번째 단어의 11번째 영상, 11_09.MP4 처리 완료.
#
# 9번째 단어의 12번째 영상, 12_09.MP4 처리 시작.
# 9번째 단어의 12번째 영상, 12_09.MP4 처리 완료.
#
# 9번째 단어의 13번째 영상, 13_09.MP4 처리 시작.
# 9번째 단어의 13번째 영상, 13_09.MP4 처리 완료.
#
# 9번째 단어의 14번째 영상, 14_09.MP4 처리 시작.
# 9번째 단어의 14번째 영상, 14_09.MP4 처리 완료.
#
# 9번째 단어의 15번째 영상, 15_09.MP4 처리 시작.
# 9번째 단어의 15번째 영상, 15_09.MP4 처리 완료.
#
# 9번째 단어의 16번째 영상, 16_09.MP4 처리 시작.
# 9번째 단어의 16번째 영상, 16_09.MP4 처리 완료.
#
# 9번째 단어의 17번째 영상, 17_09.MP4 는 존재하지 않습니다. Skipping...
# 9번째 단어의 18번째 영상, 18_09.MP4 는 존재하지 않습니다. Skipping...
# 9번째 단어의 19번째 영상, 19_09.MP4 처리 시작.
# 9번째 단어의 19번째 영상, 19_09.MP4 처리 완료.
#
# 10번째 단어의 0번째 영상, 00_10.MP4 처리 시작.
# 인식 안됨
# 10번째 단어의 0번째 영상, 00_10.MP4 처리 완료.
#
# 10번째 단어의 1번째 영상, 01_10.MP4 는 존재하지 않습니다. Skipping...
# 10번째 단어의 2번째 영상, 02_10.MP4 처리 시작.
# 10번째 단어의 2번째 영상, 02_10.MP4 처리 완료.
#
# 10번째 단어의 3번째 영상, 03_10.MP4 처리 시작.
# 10번째 단어의 3번째 영상, 03_10.MP4 처리 완료.
#
# 10번째 단어의 4번째 영상, 04_10.MP4 처리 시작.
# 10번째 단어의 4번째 영상, 04_10.MP4 처리 완료.
#
# 10번째 단어의 5번째 영상, 05_10.MP4 는 존재하지 않습니다. Skipping...
# 10번째 단어의 6번째 영상, 06_10.MP4 처리 시작.
# 10번째 단어의 6번째 영상, 06_10.MP4 처리 완료.
#
# 10번째 단어의 7번째 영상, 07_10.MP4 처리 시작.
# 10번째 단어의 7번째 영상, 07_10.MP4 처리 완료.
#
# 10번째 단어의 8번째 영상, 08_10.MP4 처리 시작.
# 10번째 단어의 8번째 영상, 08_10.MP4 처리 완료.
#
# 10번째 단어의 9번째 영상, 09_10.MP4 는 존재하지 않습니다. Skipping...
# 10번째 단어의 10번째 영상, 10_10.MP4 처리 시작.
# 10번째 단어의 10번째 영상, 10_10.MP4 처리 완료.
#
# 10번째 단어의 11번째 영상, 11_10.MP4 처리 시작.
# 10번째 단어의 11번째 영상, 11_10.MP4 처리 완료.
#
# 10번째 단어의 12번째 영상, 12_10.MP4 처리 시작.
# 10번째 단어의 12번째 영상, 12_10.MP4 처리 완료.
#
# 10번째 단어의 13번째 영상, 13_10.MP4 처리 시작.
# 10번째 단어의 13번째 영상, 13_10.MP4 처리 완료.
#
# 10번째 단어의 14번째 영상, 14_10.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 10번째 단어의 14번째 영상, 14_10.MP4 처리 완료.
#
# 10번째 단어의 15번째 영상, 15_10.MP4 처리 시작.
# 10번째 단어의 15번째 영상, 15_10.MP4 처리 완료.
#
# 10번째 단어의 16번째 영상, 16_10.MP4 처리 시작.
# 10번째 단어의 16번째 영상, 16_10.MP4 처리 완료.
#
# 10번째 단어의 17번째 영상, 17_10.MP4 는 존재하지 않습니다. Skipping...
# 10번째 단어의 18번째 영상, 18_10.MP4 는 존재하지 않습니다. Skipping...
# 10번째 단어의 19번째 영상, 19_10.MP4 처리 시작.
# 10번째 단어의 19번째 영상, 19_10.MP4 처리 완료.
#
# 11번째 단어의 0번째 영상, 00_11.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 11번째 단어의 0번째 영상, 00_11.MP4 처리 완료.
#
# 11번째 단어의 1번째 영상, 01_11.MP4 처리 시작.
# 11번째 단어의 1번째 영상, 01_11.MP4 처리 완료.
#
# 11번째 단어의 2번째 영상, 02_11.MP4 처리 시작.
# 11번째 단어의 2번째 영상, 02_11.MP4 처리 완료.
#
# 11번째 단어의 3번째 영상, 03_11.MP4 처리 시작.
# 11번째 단어의 3번째 영상, 03_11.MP4 처리 완료.
#
# 11번째 단어의 4번째 영상, 04_11.MP4 처리 시작.
# 11번째 단어의 4번째 영상, 04_11.MP4 처리 완료.
#
# 11번째 단어의 5번째 영상, 05_11.MP4 는 존재하지 않습니다. Skipping...
# 11번째 단어의 6번째 영상, 06_11.MP4 는 존재하지 않습니다. Skipping...
# 11번째 단어의 7번째 영상, 07_11.MP4 처리 시작.
# 11번째 단어의 7번째 영상, 07_11.MP4 처리 완료.
#
# 11번째 단어의 8번째 영상, 08_11.MP4 는 존재하지 않습니다. Skipping...
# 11번째 단어의 9번째 영상, 09_11.MP4 처리 시작.
# 11번째 단어의 9번째 영상, 09_11.MP4 처리 완료.
#
# 11번째 단어의 10번째 영상, 10_11.MP4 처리 시작.
# 11번째 단어의 10번째 영상, 10_11.MP4 처리 완료.
#
# 11번째 단어의 11번째 영상, 11_11.MP4 처리 시작.
# 11번째 단어의 11번째 영상, 11_11.MP4 처리 완료.
#
# 11번째 단어의 12번째 영상, 12_11.MP4 처리 시작.
# 11번째 단어의 12번째 영상, 12_11.MP4 처리 완료.
#
# 11번째 단어의 13번째 영상, 13_11.MP4 는 존재하지 않습니다. Skipping...
# 11번째 단어의 14번째 영상, 14_11.MP4 는 존재하지 않습니다. Skipping...
# 11번째 단어의 15번째 영상, 15_11.MP4 처리 시작.
# 11번째 단어의 15번째 영상, 15_11.MP4 처리 완료.
#
# 11번째 단어의 16번째 영상, 16_11.MP4 처리 시작.
# 11번째 단어의 16번째 영상, 16_11.MP4 처리 완료.
#
# 11번째 단어의 17번째 영상, 17_11.MP4 는 존재하지 않습니다. Skipping...
# 11번째 단어의 18번째 영상, 18_11.MP4 는 존재하지 않습니다. Skipping...
# 11번째 단어의 19번째 영상, 19_11.MP4 처리 시작.
# 11번째 단어의 19번째 영상, 19_11.MP4 처리 완료.
#
# 12번째 단어의 0번째 영상, 00_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 1번째 영상, 01_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 2번째 영상, 02_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 3번째 영상, 03_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 4번째 영상, 04_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 5번째 영상, 05_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 6번째 영상, 06_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 7번째 영상, 07_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 8번째 영상, 08_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 9번째 영상, 09_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 10번째 영상, 10_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 11번째 영상, 11_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 12번째 영상, 12_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 13번째 영상, 13_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 14번째 영상, 14_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 15번째 영상, 15_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 16번째 영상, 16_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 17번째 영상, 17_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 18번째 영상, 18_12.MP4 는 존재하지 않습니다. Skipping...
# 12번째 단어의 19번째 영상, 19_12.MP4 는 존재하지 않습니다. Skipping...
# 13번째 단어의 0번째 영상, 00_13.MP4 처리 시작.
# 13번째 단어의 0번째 영상, 00_13.MP4 처리 완료.
#
# 13번째 단어의 1번째 영상, 01_13.MP4 처리 시작.
# 13번째 단어의 1번째 영상, 01_13.MP4 처리 완료.
#
# 13번째 단어의 2번째 영상, 02_13.MP4 처리 시작.
# 13번째 단어의 2번째 영상, 02_13.MP4 처리 완료.
#
# 13번째 단어의 3번째 영상, 03_13.MP4 처리 시작.
# 13번째 단어의 3번째 영상, 03_13.MP4 처리 완료.
#
# 13번째 단어의 4번째 영상, 04_13.MP4 처리 시작.
# 13번째 단어의 4번째 영상, 04_13.MP4 처리 완료.
#
# 13번째 단어의 5번째 영상, 05_13.MP4 처리 시작.
# 13번째 단어의 5번째 영상, 05_13.MP4 처리 완료.
#
# 13번째 단어의 6번째 영상, 06_13.MP4 처리 시작.
# 13번째 단어의 6번째 영상, 06_13.MP4 처리 완료.
#
# 13번째 단어의 7번째 영상, 07_13.MP4 처리 시작.
# 13번째 단어의 7번째 영상, 07_13.MP4 처리 완료.
#
# 13번째 단어의 8번째 영상, 08_13.MP4 처리 시작.
# 13번째 단어의 8번째 영상, 08_13.MP4 처리 완료.
#
# 13번째 단어의 9번째 영상, 09_13.MP4 처리 시작.
# 13번째 단어의 9번째 영상, 09_13.MP4 처리 완료.
#
# 13번째 단어의 10번째 영상, 10_13.MP4 처리 시작.
# 13번째 단어의 10번째 영상, 10_13.MP4 처리 완료.
#
# 13번째 단어의 11번째 영상, 11_13.MP4 처리 시작.
# 13번째 단어의 11번째 영상, 11_13.MP4 처리 완료.
#
# 13번째 단어의 12번째 영상, 12_13.MP4 처리 시작.
# 13번째 단어의 12번째 영상, 12_13.MP4 처리 완료.
#
# 13번째 단어의 13번째 영상, 13_13.MP4 처리 시작.
# 13번째 단어의 13번째 영상, 13_13.MP4 처리 완료.
#
# 13번째 단어의 14번째 영상, 14_13.MP4 처리 시작.
# 13번째 단어의 14번째 영상, 14_13.MP4 처리 완료.
#
# 13번째 단어의 15번째 영상, 15_13.MP4 처리 시작.
# 13번째 단어의 15번째 영상, 15_13.MP4 처리 완료.
#
# 13번째 단어의 16번째 영상, 16_13.MP4 처리 시작.
# 13번째 단어의 16번째 영상, 16_13.MP4 처리 완료.
#
# 13번째 단어의 17번째 영상, 17_13.MP4 는 존재하지 않습니다. Skipping...
# 13번째 단어의 18번째 영상, 18_13.MP4 는 존재하지 않습니다. Skipping...
# 13번째 단어의 19번째 영상, 19_13.MP4 처리 시작.
# 13번째 단어의 19번째 영상, 19_13.MP4 처리 완료.
#
# 14번째 단어의 0번째 영상, 00_14.MP4 처리 시작.
# 14번째 단어의 0번째 영상, 00_14.MP4 처리 완료.
#
# 14번째 단어의 1번째 영상, 01_14.MP4 처리 시작.
# 14번째 단어의 1번째 영상, 01_14.MP4 처리 완료.
#
# 14번째 단어의 2번째 영상, 02_14.MP4 처리 시작.
# 14번째 단어의 2번째 영상, 02_14.MP4 처리 완료.
#
# 14번째 단어의 3번째 영상, 03_14.MP4 처리 시작.
# 14번째 단어의 3번째 영상, 03_14.MP4 처리 완료.
#
# 14번째 단어의 4번째 영상, 04_14.MP4 처리 시작.
# 14번째 단어의 4번째 영상, 04_14.MP4 처리 완료.
#
# 14번째 단어의 5번째 영상, 05_14.MP4 처리 시작.
# 14번째 단어의 5번째 영상, 05_14.MP4 처리 완료.
#
# 14번째 단어의 6번째 영상, 06_14.MP4 는 존재하지 않습니다. Skipping...
# 14번째 단어의 7번째 영상, 07_14.MP4 는 존재하지 않습니다. Skipping...
# 14번째 단어의 8번째 영상, 08_14.MP4 처리 시작.
# 14번째 단어의 8번째 영상, 08_14.MP4 처리 완료.
#
# 14번째 단어의 9번째 영상, 09_14.MP4 처리 시작.
# 14번째 단어의 9번째 영상, 09_14.MP4 처리 완료.
#
# 14번째 단어의 10번째 영상, 10_14.MP4 처리 시작.
# 14번째 단어의 10번째 영상, 10_14.MP4 처리 완료.
#
# 14번째 단어의 11번째 영상, 11_14.MP4 처리 시작.
# 14번째 단어의 11번째 영상, 11_14.MP4 처리 완료.
#
# 14번째 단어의 12번째 영상, 12_14.MP4 처리 시작.
# 14번째 단어의 12번째 영상, 12_14.MP4 처리 완료.
#
# 14번째 단어의 13번째 영상, 13_14.MP4 처리 시작.
# 14번째 단어의 13번째 영상, 13_14.MP4 처리 완료.
#
# 14번째 단어의 14번째 영상, 14_14.MP4 처리 시작.
# 14번째 단어의 14번째 영상, 14_14.MP4 처리 완료.
#
# 14번째 단어의 15번째 영상, 15_14.MP4 는 존재하지 않습니다. Skipping...
# 14번째 단어의 16번째 영상, 16_14.MP4 처리 시작.
# 14번째 단어의 16번째 영상, 16_14.MP4 처리 완료.
#
# 14번째 단어의 17번째 영상, 17_14.MP4 는 존재하지 않습니다. Skipping...
# 14번째 단어의 18번째 영상, 18_14.MP4 는 존재하지 않습니다. Skipping...
# 14번째 단어의 19번째 영상, 19_14.MP4 처리 시작.
# 14번째 단어의 19번째 영상, 19_14.MP4 처리 완료.
#
# 15번째 단어의 0번째 영상, 00_15.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 15번째 단어의 0번째 영상, 00_15.MP4 처리 완료.
#
# 15번째 단어의 1번째 영상, 01_15.MP4 처리 시작.
# 15번째 단어의 1번째 영상, 01_15.MP4 처리 완료.
#
# 15번째 단어의 2번째 영상, 02_15.MP4 처리 시작.
# 15번째 단어의 2번째 영상, 02_15.MP4 처리 완료.
#
# 15번째 단어의 3번째 영상, 03_15.MP4 처리 시작.
# 15번째 단어의 3번째 영상, 03_15.MP4 처리 완료.
#
# 15번째 단어의 4번째 영상, 04_15.MP4 는 존재하지 않습니다. Skipping...
# 15번째 단어의 5번째 영상, 05_15.MP4 처리 시작.
# 15번째 단어의 5번째 영상, 05_15.MP4 처리 완료.
#
# 15번째 단어의 6번째 영상, 06_15.MP4 처리 시작.
# 15번째 단어의 6번째 영상, 06_15.MP4 처리 완료.
#
# 15번째 단어의 7번째 영상, 07_15.MP4 는 존재하지 않습니다. Skipping...
# 15번째 단어의 8번째 영상, 08_15.MP4 처리 시작.
# 15번째 단어의 8번째 영상, 08_15.MP4 처리 완료.
#
# 15번째 단어의 9번째 영상, 09_15.MP4 처리 시작.
# 15번째 단어의 9번째 영상, 09_15.MP4 처리 완료.
#
# 15번째 단어의 10번째 영상, 10_15.MP4 처리 시작.
# 15번째 단어의 10번째 영상, 10_15.MP4 처리 완료.
#
# 15번째 단어의 11번째 영상, 11_15.MP4 처리 시작.
# 15번째 단어의 11번째 영상, 11_15.MP4 처리 완료.
#
# 15번째 단어의 12번째 영상, 12_15.MP4 처리 시작.
# 15번째 단어의 12번째 영상, 12_15.MP4 처리 완료.
#
# 15번째 단어의 13번째 영상, 13_15.MP4 처리 시작.
# 15번째 단어의 13번째 영상, 13_15.MP4 처리 완료.
#
# 15번째 단어의 14번째 영상, 14_15.MP4 처리 시작.
# 15번째 단어의 14번째 영상, 14_15.MP4 처리 완료.
#
# 15번째 단어의 15번째 영상, 15_15.MP4 는 존재하지 않습니다. Skipping...
# 15번째 단어의 16번째 영상, 16_15.MP4 처리 시작.
# 15번째 단어의 16번째 영상, 16_15.MP4 처리 완료.
#
# 15번째 단어의 17번째 영상, 17_15.MP4 는 존재하지 않습니다. Skipping...
# 15번째 단어의 18번째 영상, 18_15.MP4 는 존재하지 않습니다. Skipping...
# 15번째 단어의 19번째 영상, 19_15.MP4 처리 시작.
# 15번째 단어의 19번째 영상, 19_15.MP4 처리 완료.
#
# 16번째 단어의 0번째 영상, 00_16.MP4 처리 시작.
# 16번째 단어의 0번째 영상, 00_16.MP4 처리 완료.
#
# 16번째 단어의 1번째 영상, 01_16.MP4 처리 시작.
# 16번째 단어의 1번째 영상, 01_16.MP4 처리 완료.
#
# 16번째 단어의 2번째 영상, 02_16.MP4 처리 시작.
# 16번째 단어의 2번째 영상, 02_16.MP4 처리 완료.
#
# 16번째 단어의 3번째 영상, 03_16.MP4 처리 시작.
# 16번째 단어의 3번째 영상, 03_16.MP4 처리 완료.
#
# 16번째 단어의 4번째 영상, 04_16.MP4 는 존재하지 않습니다. Skipping...
# 16번째 단어의 5번째 영상, 05_16.MP4 는 존재하지 않습니다. Skipping...
# 16번째 단어의 6번째 영상, 06_16.MP4 는 존재하지 않습니다. Skipping...
# 16번째 단어의 7번째 영상, 07_16.MP4 처리 시작.
# 16번째 단어의 7번째 영상, 07_16.MP4 처리 완료.
#
# 16번째 단어의 8번째 영상, 08_16.MP4 처리 시작.
# 16번째 단어의 8번째 영상, 08_16.MP4 처리 완료.
#
# 16번째 단어의 9번째 영상, 09_16.MP4 처리 시작.
# 16번째 단어의 9번째 영상, 09_16.MP4 처리 완료.
#
# 16번째 단어의 10번째 영상, 10_16.MP4 처리 시작.
# 16번째 단어의 10번째 영상, 10_16.MP4 처리 완료.
#
# 16번째 단어의 11번째 영상, 11_16.MP4 처리 시작.
# 16번째 단어의 11번째 영상, 11_16.MP4 처리 완료.
#
# 16번째 단어의 12번째 영상, 12_16.MP4 처리 시작.
# 16번째 단어의 12번째 영상, 12_16.MP4 처리 완료.
#
# 16번째 단어의 13번째 영상, 13_16.MP4 처리 시작.
# 16번째 단어의 13번째 영상, 13_16.MP4 처리 완료.
#
# 16번째 단어의 14번째 영상, 14_16.MP4 처리 시작.
# 16번째 단어의 14번째 영상, 14_16.MP4 처리 완료.
#
# 16번째 단어의 15번째 영상, 15_16.MP4 처리 시작.
# 16번째 단어의 15번째 영상, 15_16.MP4 처리 완료.
#
# 16번째 단어의 16번째 영상, 16_16.MP4 처리 시작.
# 16번째 단어의 16번째 영상, 16_16.MP4 처리 완료.
#
# 16번째 단어의 17번째 영상, 17_16.MP4 는 존재하지 않습니다. Skipping...
# 16번째 단어의 18번째 영상, 18_16.MP4 는 존재하지 않습니다. Skipping...
# 16번째 단어의 19번째 영상, 19_16.MP4 처리 시작.
# 16번째 단어의 19번째 영상, 19_16.MP4 처리 완료.
#
# 17번째 단어의 0번째 영상, 00_17.MP4 처리 시작.
# 17번째 단어의 0번째 영상, 00_17.MP4 처리 완료.
#
# 17번째 단어의 1번째 영상, 01_17.MP4 처리 시작.
# 17번째 단어의 1번째 영상, 01_17.MP4 처리 완료.
#
# 17번째 단어의 2번째 영상, 02_17.MP4 처리 시작.
# 17번째 단어의 2번째 영상, 02_17.MP4 처리 완료.
#
# 17번째 단어의 3번째 영상, 03_17.MP4 처리 시작.
# 17번째 단어의 3번째 영상, 03_17.MP4 처리 완료.
#
# 17번째 단어의 4번째 영상, 04_17.MP4 처리 시작.
# 17번째 단어의 4번째 영상, 04_17.MP4 처리 완료.
#
# 17번째 단어의 5번째 영상, 05_17.MP4 처리 시작.
# 17번째 단어의 5번째 영상, 05_17.MP4 처리 완료.
#
# 17번째 단어의 6번째 영상, 06_17.MP4 는 존재하지 않습니다. Skipping...
# 17번째 단어의 7번째 영상, 07_17.MP4 처리 시작.
# 17번째 단어의 7번째 영상, 07_17.MP4 처리 완료.
#
# 17번째 단어의 8번째 영상, 08_17.MP4 처리 시작.
# 17번째 단어의 8번째 영상, 08_17.MP4 처리 완료.
#
# 17번째 단어의 9번째 영상, 09_17.MP4 처리 시작.
# 17번째 단어의 9번째 영상, 09_17.MP4 처리 완료.
#
# 17번째 단어의 10번째 영상, 10_17.MP4 처리 시작.
# 17번째 단어의 10번째 영상, 10_17.MP4 처리 완료.
#
# 17번째 단어의 11번째 영상, 11_17.MP4 처리 시작.
# 17번째 단어의 11번째 영상, 11_17.MP4 처리 완료.
#
# 17번째 단어의 12번째 영상, 12_17.MP4 처리 시작.
# 17번째 단어의 12번째 영상, 12_17.MP4 처리 완료.
#
# 17번째 단어의 13번째 영상, 13_17.MP4 처리 시작.
# 17번째 단어의 13번째 영상, 13_17.MP4 처리 완료.
#
# 17번째 단어의 14번째 영상, 14_17.MP4 처리 시작.
# 17번째 단어의 14번째 영상, 14_17.MP4 처리 완료.
#
# 17번째 단어의 15번째 영상, 15_17.MP4 처리 시작.
# 17번째 단어의 15번째 영상, 15_17.MP4 처리 완료.
#
# 17번째 단어의 16번째 영상, 16_17.MP4 처리 시작.
# 17번째 단어의 16번째 영상, 16_17.MP4 처리 완료.
#
# 17번째 단어의 17번째 영상, 17_17.MP4 는 존재하지 않습니다. Skipping...
# 17번째 단어의 18번째 영상, 18_17.MP4 는 존재하지 않습니다. Skipping...
# 17번째 단어의 19번째 영상, 19_17.MP4 처리 시작.
# 17번째 단어의 19번째 영상, 19_17.MP4 처리 완료.
#
# 18번째 단어의 0번째 영상, 00_18.MP4 처리 시작.
# 18번째 단어의 0번째 영상, 00_18.MP4 처리 완료.
#
# 18번째 단어의 1번째 영상, 01_18.MP4 처리 시작.
# 18번째 단어의 1번째 영상, 01_18.MP4 처리 완료.
#
# 18번째 단어의 2번째 영상, 02_18.MP4 는 존재하지 않습니다. Skipping...
# 18번째 단어의 3번째 영상, 03_18.MP4 처리 시작.
# 18번째 단어의 3번째 영상, 03_18.MP4 처리 완료.
#
# 18번째 단어의 4번째 영상, 04_18.MP4 처리 시작.
# 18번째 단어의 4번째 영상, 04_18.MP4 처리 완료.
#
# 18번째 단어의 5번째 영상, 05_18.MP4 는 존재하지 않습니다. Skipping...
# 18번째 단어의 6번째 영상, 06_18.MP4 는 존재하지 않습니다. Skipping...
# 18번째 단어의 7번째 영상, 07_18.MP4 처리 시작.
# 18번째 단어의 7번째 영상, 07_18.MP4 처리 완료.
#
# 18번째 단어의 8번째 영상, 08_18.MP4 처리 시작.
# 18번째 단어의 8번째 영상, 08_18.MP4 처리 완료.
#
# 18번째 단어의 9번째 영상, 09_18.MP4 처리 시작.
# 18번째 단어의 9번째 영상, 09_18.MP4 처리 완료.
#
# 18번째 단어의 10번째 영상, 10_18.MP4 처리 시작.
# 18번째 단어의 10번째 영상, 10_18.MP4 처리 완료.
#
# 18번째 단어의 11번째 영상, 11_18.MP4 처리 시작.
# 18번째 단어의 11번째 영상, 11_18.MP4 처리 완료.
#
# 18번째 단어의 12번째 영상, 12_18.MP4 처리 시작.
# 18번째 단어의 12번째 영상, 12_18.MP4 처리 완료.
#
# 18번째 단어의 13번째 영상, 13_18.MP4 처리 시작.
# 18번째 단어의 13번째 영상, 13_18.MP4 처리 완료.
#
# 18번째 단어의 14번째 영상, 14_18.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 18번째 단어의 14번째 영상, 14_18.MP4 처리 완료.
#
# 18번째 단어의 15번째 영상, 15_18.MP4 처리 시작.
# 18번째 단어의 15번째 영상, 15_18.MP4 처리 완료.
#
# 18번째 단어의 16번째 영상, 16_18.MP4 처리 시작.
# 18번째 단어의 16번째 영상, 16_18.MP4 처리 완료.
#
# 18번째 단어의 17번째 영상, 17_18.MP4 는 존재하지 않습니다. Skipping...
# 18번째 단어의 18번째 영상, 18_18.MP4 는 존재하지 않습니다. Skipping...
# 18번째 단어의 19번째 영상, 19_18.MP4 처리 시작.
# 18번째 단어의 19번째 영상, 19_18.MP4 처리 완료.
#
# 19번째 단어의 0번째 영상, 00_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 1번째 영상, 01_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 2번째 영상, 02_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 3번째 영상, 03_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 4번째 영상, 04_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 5번째 영상, 05_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 6번째 영상, 06_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 7번째 영상, 07_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 8번째 영상, 08_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 9번째 영상, 09_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 10번째 영상, 10_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 11번째 영상, 11_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 12번째 영상, 12_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 13번째 영상, 13_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 14번째 영상, 14_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 15번째 영상, 15_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 16번째 영상, 16_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 17번째 영상, 17_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 18번째 영상, 18_19.MP4 는 존재하지 않습니다. Skipping...
# 19번째 단어의 19번째 영상, 19_19.MP4 는 존재하지 않습니다. Skipping...
# 20번째 단어의 0번째 영상, 00_20.MP4 처리 시작.
# 20번째 단어의 0번째 영상, 00_20.MP4 처리 완료.
#
# 20번째 단어의 1번째 영상, 01_20.MP4 처리 시작.
# 20번째 단어의 1번째 영상, 01_20.MP4 처리 완료.
#
# 20번째 단어의 2번째 영상, 02_20.MP4 처리 시작.
# 20번째 단어의 2번째 영상, 02_20.MP4 처리 완료.
#
# 20번째 단어의 3번째 영상, 03_20.MP4 처리 시작.
# 20번째 단어의 3번째 영상, 03_20.MP4 처리 완료.
#
# 20번째 단어의 4번째 영상, 04_20.MP4 처리 시작.
# 20번째 단어의 4번째 영상, 04_20.MP4 처리 완료.
#
# 20번째 단어의 5번째 영상, 05_20.MP4 처리 시작.
# 20번째 단어의 5번째 영상, 05_20.MP4 처리 완료.
#
# 20번째 단어의 6번째 영상, 06_20.MP4 처리 시작.
# 20번째 단어의 6번째 영상, 06_20.MP4 처리 완료.
#
# 20번째 단어의 7번째 영상, 07_20.MP4 처리 시작.
# 20번째 단어의 7번째 영상, 07_20.MP4 처리 완료.
#
# 20번째 단어의 8번째 영상, 08_20.MP4 처리 시작.
# 20번째 단어의 8번째 영상, 08_20.MP4 처리 완료.
#
# 20번째 단어의 9번째 영상, 09_20.MP4 처리 시작.
# 20번째 단어의 9번째 영상, 09_20.MP4 처리 완료.
#
# 20번째 단어의 10번째 영상, 10_20.MP4 처리 시작.
# 20번째 단어의 10번째 영상, 10_20.MP4 처리 완료.
#
# 20번째 단어의 11번째 영상, 11_20.MP4 처리 시작.
# 20번째 단어의 11번째 영상, 11_20.MP4 처리 완료.
#
# 20번째 단어의 12번째 영상, 12_20.MP4 처리 시작.
# 20번째 단어의 12번째 영상, 12_20.MP4 처리 완료.
#
# 20번째 단어의 13번째 영상, 13_20.MP4 처리 시작.
# 20번째 단어의 13번째 영상, 13_20.MP4 처리 완료.
#
# 20번째 단어의 14번째 영상, 14_20.MP4 는 존재하지 않습니다. Skipping...
# 20번째 단어의 15번째 영상, 15_20.MP4 처리 시작.
# 20번째 단어의 15번째 영상, 15_20.MP4 처리 완료.
#
# 20번째 단어의 16번째 영상, 16_20.MP4 처리 시작.
# 20번째 단어의 16번째 영상, 16_20.MP4 처리 완료.
#
# 20번째 단어의 17번째 영상, 17_20.MP4 는 존재하지 않습니다. Skipping...
# 20번째 단어의 18번째 영상, 18_20.MP4 는 존재하지 않습니다. Skipping...
# 20번째 단어의 19번째 영상, 19_20.MP4 처리 시작.
# 20번째 단어의 19번째 영상, 19_20.MP4 처리 완료.
#
# 21번째 단어의 0번째 영상, 00_21.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 21번째 단어의 0번째 영상, 00_21.MP4 처리 완료.
#
# 21번째 단어의 1번째 영상, 01_21.MP4 처리 시작.
# 21번째 단어의 1번째 영상, 01_21.MP4 처리 완료.
#
# 21번째 단어의 2번째 영상, 02_21.MP4 처리 시작.
# 21번째 단어의 2번째 영상, 02_21.MP4 처리 완료.
#
# 21번째 단어의 3번째 영상, 03_21.MP4 처리 시작.
# 21번째 단어의 3번째 영상, 03_21.MP4 처리 완료.
#
# 21번째 단어의 4번째 영상, 04_21.MP4 처리 시작.
# 21번째 단어의 4번째 영상, 04_21.MP4 처리 완료.
#
# 21번째 단어의 5번째 영상, 05_21.MP4 는 존재하지 않습니다. Skipping...
# 21번째 단어의 6번째 영상, 06_21.MP4 처리 시작.
# 21번째 단어의 6번째 영상, 06_21.MP4 처리 완료.
#
# 21번째 단어의 7번째 영상, 07_21.MP4 처리 시작.
# 21번째 단어의 7번째 영상, 07_21.MP4 처리 완료.
#
# 21번째 단어의 8번째 영상, 08_21.MP4 처리 시작.
# 21번째 단어의 8번째 영상, 08_21.MP4 처리 완료.
#
# 21번째 단어의 9번째 영상, 09_21.MP4 처리 시작.
# 21번째 단어의 9번째 영상, 09_21.MP4 처리 완료.
#
# 21번째 단어의 10번째 영상, 10_21.MP4 처리 시작.
# 21번째 단어의 10번째 영상, 10_21.MP4 처리 완료.
#
# 21번째 단어의 11번째 영상, 11_21.MP4 처리 시작.
# 21번째 단어의 11번째 영상, 11_21.MP4 처리 완료.
#
# 21번째 단어의 12번째 영상, 12_21.MP4 처리 시작.
# 21번째 단어의 12번째 영상, 12_21.MP4 처리 완료.
#
# 21번째 단어의 13번째 영상, 13_21.MP4 처리 시작.
# 21번째 단어의 13번째 영상, 13_21.MP4 처리 완료.
#
# 21번째 단어의 14번째 영상, 14_21.MP4 처리 시작.
# 21번째 단어의 14번째 영상, 14_21.MP4 처리 완료.
#
# 21번째 단어의 15번째 영상, 15_21.MP4 처리 시작.
# 21번째 단어의 15번째 영상, 15_21.MP4 처리 완료.
#
# 21번째 단어의 16번째 영상, 16_21.MP4 처리 시작.
# 21번째 단어의 16번째 영상, 16_21.MP4 처리 완료.
#
# 21번째 단어의 17번째 영상, 17_21.MP4 는 존재하지 않습니다. Skipping...
# 21번째 단어의 18번째 영상, 18_21.MP4 는 존재하지 않습니다. Skipping...
# 21번째 단어의 19번째 영상, 19_21.MP4 처리 시작.
# 21번째 단어의 19번째 영상, 19_21.MP4 처리 완료.
#
# 22번째 단어의 0번째 영상, 00_22.MP4 처리 시작.
# 22번째 단어의 0번째 영상, 00_22.MP4 처리 완료.
#
# 22번째 단어의 1번째 영상, 01_22.MP4 처리 시작.
# 22번째 단어의 1번째 영상, 01_22.MP4 처리 완료.
#
# 22번째 단어의 2번째 영상, 02_22.MP4 처리 시작.
# 22번째 단어의 2번째 영상, 02_22.MP4 처리 완료.
#
# 22번째 단어의 3번째 영상, 03_22.MP4 처리 시작.
# 22번째 단어의 3번째 영상, 03_22.MP4 처리 완료.
#
# 22번째 단어의 4번째 영상, 04_22.MP4 는 존재하지 않습니다. Skipping...
# 22번째 단어의 5번째 영상, 05_22.MP4 처리 시작.
# 22번째 단어의 5번째 영상, 05_22.MP4 처리 완료.
#
# 22번째 단어의 6번째 영상, 06_22.MP4 는 존재하지 않습니다. Skipping...
# 22번째 단어의 7번째 영상, 07_22.MP4 처리 시작.
# 22번째 단어의 7번째 영상, 07_22.MP4 처리 완료.
#
# 22번째 단어의 8번째 영상, 08_22.MP4 처리 시작.
# 22번째 단어의 8번째 영상, 08_22.MP4 처리 완료.
#
# 22번째 단어의 9번째 영상, 09_22.MP4 처리 시작.
# 22번째 단어의 9번째 영상, 09_22.MP4 처리 완료.
#
# 22번째 단어의 10번째 영상, 10_22.MP4 처리 시작.
# 22번째 단어의 10번째 영상, 10_22.MP4 처리 완료.
#
# 22번째 단어의 11번째 영상, 11_22.MP4 처리 시작.
# 22번째 단어의 11번째 영상, 11_22.MP4 처리 완료.
#
# 22번째 단어의 12번째 영상, 12_22.MP4 처리 시작.
# 22번째 단어의 12번째 영상, 12_22.MP4 처리 완료.
#
# 22번째 단어의 13번째 영상, 13_22.MP4 처리 시작.
# 22번째 단어의 13번째 영상, 13_22.MP4 처리 완료.
#
# 22번째 단어의 14번째 영상, 14_22.MP4 처리 시작.
# 22번째 단어의 14번째 영상, 14_22.MP4 처리 완료.
#
# 22번째 단어의 15번째 영상, 15_22.MP4 처리 시작.
# 22번째 단어의 15번째 영상, 15_22.MP4 처리 완료.
#
# 22번째 단어의 16번째 영상, 16_22.MP4 처리 시작.
# 22번째 단어의 16번째 영상, 16_22.MP4 처리 완료.
#
# 22번째 단어의 17번째 영상, 17_22.MP4 는 존재하지 않습니다. Skipping...
# 22번째 단어의 18번째 영상, 18_22.MP4 는 존재하지 않습니다. Skipping...
# 22번째 단어의 19번째 영상, 19_22.MP4 처리 시작.
# 22번째 단어의 19번째 영상, 19_22.MP4 처리 완료.
#
# 23번째 단어의 0번째 영상, 00_23.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 23번째 단어의 0번째 영상, 00_23.MP4 처리 완료.
#
# 23번째 단어의 1번째 영상, 01_23.MP4 처리 시작.
# 23번째 단어의 1번째 영상, 01_23.MP4 처리 완료.
#
# 23번째 단어의 2번째 영상, 02_23.MP4 는 존재하지 않습니다. Skipping...
# 23번째 단어의 3번째 영상, 03_23.MP4 처리 시작.
# 23번째 단어의 3번째 영상, 03_23.MP4 처리 완료.
#
# 23번째 단어의 4번째 영상, 04_23.MP4 처리 시작.
# 23번째 단어의 4번째 영상, 04_23.MP4 처리 완료.
#
# 23번째 단어의 5번째 영상, 05_23.MP4 처리 시작.
# 23번째 단어의 5번째 영상, 05_23.MP4 처리 완료.
#
# 23번째 단어의 6번째 영상, 06_23.MP4 처리 시작.
# 23번째 단어의 6번째 영상, 06_23.MP4 처리 완료.
#
# 23번째 단어의 7번째 영상, 07_23.MP4 처리 시작.
# 23번째 단어의 7번째 영상, 07_23.MP4 처리 완료.
#
# 23번째 단어의 8번째 영상, 08_23.MP4 처리 시작.
# 23번째 단어의 8번째 영상, 08_23.MP4 처리 완료.
#
# 23번째 단어의 9번째 영상, 09_23.MP4 처리 시작.
# 23번째 단어의 9번째 영상, 09_23.MP4 처리 완료.
#
# 23번째 단어의 10번째 영상, 10_23.MP4 처리 시작.
# 23번째 단어의 10번째 영상, 10_23.MP4 처리 완료.
#
# 23번째 단어의 11번째 영상, 11_23.MP4 처리 시작.
# 23번째 단어의 11번째 영상, 11_23.MP4 처리 완료.
#
# 23번째 단어의 12번째 영상, 12_23.MP4 처리 시작.
# 23번째 단어의 12번째 영상, 12_23.MP4 처리 완료.
#
# 23번째 단어의 13번째 영상, 13_23.MP4 처리 시작.
# 23번째 단어의 13번째 영상, 13_23.MP4 처리 완료.
#
# 23번째 단어의 14번째 영상, 14_23.MP4 처리 시작.
# 23번째 단어의 14번째 영상, 14_23.MP4 처리 완료.
#
# 23번째 단어의 15번째 영상, 15_23.MP4 처리 시작.
# 23번째 단어의 15번째 영상, 15_23.MP4 처리 완료.
#
# 23번째 단어의 16번째 영상, 16_23.MP4 처리 시작.
# 23번째 단어의 16번째 영상, 16_23.MP4 처리 완료.
#
# 23번째 단어의 17번째 영상, 17_23.MP4 는 존재하지 않습니다. Skipping...
# 23번째 단어의 18번째 영상, 18_23.MP4 는 존재하지 않습니다. Skipping...
# 23번째 단어의 19번째 영상, 19_23.MP4 처리 시작.
# 23번째 단어의 19번째 영상, 19_23.MP4 처리 완료.
#
# 24번째 단어의 0번째 영상, 00_24.MP4 처리 시작.
# 24번째 단어의 0번째 영상, 00_24.MP4 처리 완료.
#
# 24번째 단어의 1번째 영상, 01_24.MP4 처리 시작.
# 24번째 단어의 1번째 영상, 01_24.MP4 처리 완료.
#
# 24번째 단어의 2번째 영상, 02_24.MP4 처리 시작.
# 인식 안됨
# 24번째 단어의 2번째 영상, 02_24.MP4 처리 완료.
#
# 24번째 단어의 3번째 영상, 03_24.MP4 처리 시작.
# 24번째 단어의 3번째 영상, 03_24.MP4 처리 완료.
#
# 24번째 단어의 4번째 영상, 04_24.MP4 는 존재하지 않습니다. Skipping...
# 24번째 단어의 5번째 영상, 05_24.MP4 처리 시작.
# 24번째 단어의 5번째 영상, 05_24.MP4 처리 완료.
#
# 24번째 단어의 6번째 영상, 06_24.MP4 처리 시작.
# 24번째 단어의 6번째 영상, 06_24.MP4 처리 완료.
#
# 24번째 단어의 7번째 영상, 07_24.MP4 처리 시작.
# 24번째 단어의 7번째 영상, 07_24.MP4 처리 완료.
#
# 24번째 단어의 8번째 영상, 08_24.MP4 처리 시작.
# 24번째 단어의 8번째 영상, 08_24.MP4 처리 완료.
#
# 24번째 단어의 9번째 영상, 09_24.MP4 처리 시작.
# 24번째 단어의 9번째 영상, 09_24.MP4 처리 완료.
#
# 24번째 단어의 10번째 영상, 10_24.MP4 처리 시작.
# 24번째 단어의 10번째 영상, 10_24.MP4 처리 완료.
#
# 24번째 단어의 11번째 영상, 11_24.MP4 처리 시작.
# 24번째 단어의 11번째 영상, 11_24.MP4 처리 완료.
#
# 24번째 단어의 12번째 영상, 12_24.MP4 는 존재하지 않습니다. Skipping...
# 24번째 단어의 13번째 영상, 13_24.MP4 처리 시작.
# 24번째 단어의 13번째 영상, 13_24.MP4 처리 완료.
#
# 24번째 단어의 14번째 영상, 14_24.MP4 처리 시작.
# 인식 안됨
# 24번째 단어의 14번째 영상, 14_24.MP4 처리 완료.
#
# 24번째 단어의 15번째 영상, 15_24.MP4 처리 시작.
# 24번째 단어의 15번째 영상, 15_24.MP4 처리 완료.
#
# 24번째 단어의 16번째 영상, 16_24.MP4 처리 시작.
# 24번째 단어의 16번째 영상, 16_24.MP4 처리 완료.
#
# 24번째 단어의 17번째 영상, 17_24.MP4 는 존재하지 않습니다. Skipping...
# 24번째 단어의 18번째 영상, 18_24.MP4 는 존재하지 않습니다. Skipping...
# 24번째 단어의 19번째 영상, 19_24.MP4 처리 시작.
# 24번째 단어의 19번째 영상, 19_24.MP4 처리 완료.
#
# 25번째 단어의 0번째 영상, 00_25.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 25번째 단어의 0번째 영상, 00_25.MP4 처리 완료.
#
# 25번째 단어의 1번째 영상, 01_25.MP4 는 존재하지 않습니다. Skipping...
# 25번째 단어의 2번째 영상, 02_25.MP4 처리 시작.
# 25번째 단어의 2번째 영상, 02_25.MP4 처리 완료.
#
# 25번째 단어의 3번째 영상, 03_25.MP4 처리 시작.
# 25번째 단어의 3번째 영상, 03_25.MP4 처리 완료.
#
# 25번째 단어의 4번째 영상, 04_25.MP4 는 존재하지 않습니다. Skipping...
# 25번째 단어의 5번째 영상, 05_25.MP4 는 존재하지 않습니다. Skipping...
# 25번째 단어의 6번째 영상, 06_25.MP4 처리 시작.
# 25번째 단어의 6번째 영상, 06_25.MP4 처리 완료.
#
# 25번째 단어의 7번째 영상, 07_25.MP4 처리 시작.
# 25번째 단어의 7번째 영상, 07_25.MP4 처리 완료.
#
# 25번째 단어의 8번째 영상, 08_25.MP4 처리 시작.
# 25번째 단어의 8번째 영상, 08_25.MP4 처리 완료.
#
# 25번째 단어의 9번째 영상, 09_25.MP4 는 존재하지 않습니다. Skipping...
# 25번째 단어의 10번째 영상, 10_25.MP4 처리 시작.
# 25번째 단어의 10번째 영상, 10_25.MP4 처리 완료.
#
# 25번째 단어의 11번째 영상, 11_25.MP4 처리 시작.
# 25번째 단어의 11번째 영상, 11_25.MP4 처리 완료.
#
# 25번째 단어의 12번째 영상, 12_25.MP4 처리 시작.
# 25번째 단어의 12번째 영상, 12_25.MP4 처리 완료.
#
# 25번째 단어의 13번째 영상, 13_25.MP4 처리 시작.
# 25번째 단어의 13번째 영상, 13_25.MP4 처리 완료.
#
# 25번째 단어의 14번째 영상, 14_25.MP4 처리 시작.
# 인식 안됨
# 25번째 단어의 14번째 영상, 14_25.MP4 처리 완료.
#
# 25번째 단어의 15번째 영상, 15_25.MP4 처리 시작.
# 25번째 단어의 15번째 영상, 15_25.MP4 처리 완료.
#
# 25번째 단어의 16번째 영상, 16_25.MP4 처리 시작.
# 25번째 단어의 16번째 영상, 16_25.MP4 처리 완료.
#
# 25번째 단어의 17번째 영상, 17_25.MP4 는 존재하지 않습니다. Skipping...
# 25번째 단어의 18번째 영상, 18_25.MP4 는 존재하지 않습니다. Skipping...
# 25번째 단어의 19번째 영상, 19_25.MP4 는 존재하지 않습니다. Skipping...
# 26번째 단어의 0번째 영상, 00_26.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 26번째 단어의 0번째 영상, 00_26.MP4 처리 완료.
#
# 26번째 단어의 1번째 영상, 01_26.MP4 처리 시작.
# 26번째 단어의 1번째 영상, 01_26.MP4 처리 완료.
#
# 26번째 단어의 2번째 영상, 02_26.MP4 처리 시작.
# 26번째 단어의 2번째 영상, 02_26.MP4 처리 완료.
#
# 26번째 단어의 3번째 영상, 03_26.MP4 처리 시작.
# 26번째 단어의 3번째 영상, 03_26.MP4 처리 완료.
#
# 26번째 단어의 4번째 영상, 04_26.MP4 처리 시작.
# 26번째 단어의 4번째 영상, 04_26.MP4 처리 완료.
#
# 26번째 단어의 5번째 영상, 05_26.MP4 처리 시작.
# 26번째 단어의 5번째 영상, 05_26.MP4 처리 완료.
#
# 26번째 단어의 6번째 영상, 06_26.MP4 는 존재하지 않습니다. Skipping...
# 26번째 단어의 7번째 영상, 07_26.MP4 처리 시작.
# 26번째 단어의 7번째 영상, 07_26.MP4 처리 완료.
#
# 26번째 단어의 8번째 영상, 08_26.MP4 처리 시작.
# 26번째 단어의 8번째 영상, 08_26.MP4 처리 완료.
#
# 26번째 단어의 9번째 영상, 09_26.MP4 처리 시작.
# 26번째 단어의 9번째 영상, 09_26.MP4 처리 완료.
#
# 26번째 단어의 10번째 영상, 10_26.MP4 처리 시작.
# 26번째 단어의 10번째 영상, 10_26.MP4 처리 완료.
#
# 26번째 단어의 11번째 영상, 11_26.MP4 처리 시작.
# 26번째 단어의 11번째 영상, 11_26.MP4 처리 완료.
#
# 26번째 단어의 12번째 영상, 12_26.MP4 처리 시작.
# 26번째 단어의 12번째 영상, 12_26.MP4 처리 완료.
#
# 26번째 단어의 13번째 영상, 13_26.MP4 처리 시작.
# 26번째 단어의 13번째 영상, 13_26.MP4 처리 완료.
#
# 26번째 단어의 14번째 영상, 14_26.MP4 처리 시작.
# 26번째 단어의 14번째 영상, 14_26.MP4 처리 완료.
#
# 26번째 단어의 15번째 영상, 15_26.MP4 처리 시작.
# 26번째 단어의 15번째 영상, 15_26.MP4 처리 완료.
#
# 26번째 단어의 16번째 영상, 16_26.MP4 처리 시작.
# 26번째 단어의 16번째 영상, 16_26.MP4 처리 완료.
#
# 26번째 단어의 17번째 영상, 17_26.MP4 는 존재하지 않습니다. Skipping...
# 26번째 단어의 18번째 영상, 18_26.MP4 는 존재하지 않습니다. Skipping...
# 26번째 단어의 19번째 영상, 19_26.MP4 처리 시작.
# 26번째 단어의 19번째 영상, 19_26.MP4 처리 완료.
#
# 27번째 단어의 0번째 영상, 00_27.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 27번째 단어의 0번째 영상, 00_27.MP4 처리 완료.
#
# 27번째 단어의 1번째 영상, 01_27.MP4 처리 시작.
# 27번째 단어의 1번째 영상, 01_27.MP4 처리 완료.
#
# 27번째 단어의 2번째 영상, 02_27.MP4 는 존재하지 않습니다. Skipping...
# 27번째 단어의 3번째 영상, 03_27.MP4 처리 시작.
# 27번째 단어의 3번째 영상, 03_27.MP4 처리 완료.
#
# 27번째 단어의 4번째 영상, 04_27.MP4 처리 시작.
# 27번째 단어의 4번째 영상, 04_27.MP4 처리 완료.
#
# 27번째 단어의 5번째 영상, 05_27.MP4 처리 시작.
# 27번째 단어의 5번째 영상, 05_27.MP4 처리 완료.
#
# 27번째 단어의 6번째 영상, 06_27.MP4 는 존재하지 않습니다. Skipping...
# 27번째 단어의 7번째 영상, 07_27.MP4 처리 시작.
# 27번째 단어의 7번째 영상, 07_27.MP4 처리 완료.
#
# 27번째 단어의 8번째 영상, 08_27.MP4 처리 시작.
# 27번째 단어의 8번째 영상, 08_27.MP4 처리 완료.
#
# 27번째 단어의 9번째 영상, 09_27.MP4 처리 시작.
# 27번째 단어의 9번째 영상, 09_27.MP4 처리 완료.
#
# 27번째 단어의 10번째 영상, 10_27.MP4 처리 시작.
# 27번째 단어의 10번째 영상, 10_27.MP4 처리 완료.
#
# 27번째 단어의 11번째 영상, 11_27.MP4 처리 시작.
# 27번째 단어의 11번째 영상, 11_27.MP4 처리 완료.
#
# 27번째 단어의 12번째 영상, 12_27.MP4 처리 시작.
# 27번째 단어의 12번째 영상, 12_27.MP4 처리 완료.
#
# 27번째 단어의 13번째 영상, 13_27.MP4 처리 시작.
# 27번째 단어의 13번째 영상, 13_27.MP4 처리 완료.
#
# 27번째 단어의 14번째 영상, 14_27.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 27번째 단어의 14번째 영상, 14_27.MP4 처리 완료.
#
# 27번째 단어의 15번째 영상, 15_27.MP4 처리 시작.
# 27번째 단어의 15번째 영상, 15_27.MP4 처리 완료.
#
# 27번째 단어의 16번째 영상, 16_27.MP4 처리 시작.
# 27번째 단어의 16번째 영상, 16_27.MP4 처리 완료.
#
# 27번째 단어의 17번째 영상, 17_27.MP4 는 존재하지 않습니다. Skipping...
# 27번째 단어의 18번째 영상, 18_27.MP4 는 존재하지 않습니다. Skipping...
# 27번째 단어의 19번째 영상, 19_27.MP4 처리 시작.
# 27번째 단어의 19번째 영상, 19_27.MP4 처리 완료.
#
# 28번째 단어의 0번째 영상, 00_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 1번째 영상, 01_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 2번째 영상, 02_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 3번째 영상, 03_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 4번째 영상, 04_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 5번째 영상, 05_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 6번째 영상, 06_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 7번째 영상, 07_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 8번째 영상, 08_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 9번째 영상, 09_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 10번째 영상, 10_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 11번째 영상, 11_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 12번째 영상, 12_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 13번째 영상, 13_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 14번째 영상, 14_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 15번째 영상, 15_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 16번째 영상, 16_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 17번째 영상, 17_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 18번째 영상, 18_28.MP4 는 존재하지 않습니다. Skipping...
# 28번째 단어의 19번째 영상, 19_28.MP4 는 존재하지 않습니다. Skipping...
# 29번째 단어의 0번째 영상, 00_29.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 29번째 단어의 0번째 영상, 00_29.MP4 처리 완료.
#
# 29번째 단어의 1번째 영상, 01_29.MP4 처리 시작.
# 29번째 단어의 1번째 영상, 01_29.MP4 처리 완료.
#
# 29번째 단어의 2번째 영상, 02_29.MP4 처리 시작.
# 29번째 단어의 2번째 영상, 02_29.MP4 처리 완료.
#
# 29번째 단어의 3번째 영상, 03_29.MP4 처리 시작.
# 29번째 단어의 3번째 영상, 03_29.MP4 처리 완료.
#
# 29번째 단어의 4번째 영상, 04_29.MP4 는 존재하지 않습니다. Skipping...
# 29번째 단어의 5번째 영상, 05_29.MP4 처리 시작.
# 29번째 단어의 5번째 영상, 05_29.MP4 처리 완료.
#
# 29번째 단어의 6번째 영상, 06_29.MP4 는 존재하지 않습니다. Skipping...
# 29번째 단어의 7번째 영상, 07_29.MP4 처리 시작.
# 29번째 단어의 7번째 영상, 07_29.MP4 처리 완료.
#
# 29번째 단어의 8번째 영상, 08_29.MP4 처리 시작.
# 29번째 단어의 8번째 영상, 08_29.MP4 처리 완료.
#
# 29번째 단어의 9번째 영상, 09_29.MP4 처리 시작.
# 29번째 단어의 9번째 영상, 09_29.MP4 처리 완료.
#
# 29번째 단어의 10번째 영상, 10_29.MP4 처리 시작.
# 29번째 단어의 10번째 영상, 10_29.MP4 처리 완료.
#
# 29번째 단어의 11번째 영상, 11_29.MP4 처리 시작.
# 29번째 단어의 11번째 영상, 11_29.MP4 처리 완료.
#
# 29번째 단어의 12번째 영상, 12_29.MP4 처리 시작.
# 29번째 단어의 12번째 영상, 12_29.MP4 처리 완료.
#
# 29번째 단어의 13번째 영상, 13_29.MP4 처리 시작.
# 29번째 단어의 13번째 영상, 13_29.MP4 처리 완료.
#
# 29번째 단어의 14번째 영상, 14_29.MP4 처리 시작.
# 인식 안됨
# 29번째 단어의 14번째 영상, 14_29.MP4 처리 완료.
#
# 29번째 단어의 15번째 영상, 15_29.MP4 처리 시작.
# 29번째 단어의 15번째 영상, 15_29.MP4 처리 완료.
#
# 29번째 단어의 16번째 영상, 16_29.MP4 처리 시작.
# 29번째 단어의 16번째 영상, 16_29.MP4 처리 완료.
#
# 29번째 단어의 17번째 영상, 17_29.MP4 는 존재하지 않습니다. Skipping...
# 29번째 단어의 18번째 영상, 18_29.MP4 는 존재하지 않습니다. Skipping...
# 29번째 단어의 19번째 영상, 19_29.MP4 처리 시작.
# 29번째 단어의 19번째 영상, 19_29.MP4 처리 완료.
#
# 30번째 단어의 0번째 영상, 00_30.MP4 처리 시작.
# 30번째 단어의 0번째 영상, 00_30.MP4 처리 완료.
#
# 30번째 단어의 1번째 영상, 01_30.MP4 처리 시작.
# 30번째 단어의 1번째 영상, 01_30.MP4 처리 완료.
#
# 30번째 단어의 2번째 영상, 02_30.MP4 처리 시작.
# 30번째 단어의 2번째 영상, 02_30.MP4 처리 완료.
#
# 30번째 단어의 3번째 영상, 03_30.MP4 처리 시작.
# 30번째 단어의 3번째 영상, 03_30.MP4 처리 완료.
#
# 30번째 단어의 4번째 영상, 04_30.MP4 는 존재하지 않습니다. Skipping...
# 30번째 단어의 5번째 영상, 05_30.MP4 처리 시작.
# 30번째 단어의 5번째 영상, 05_30.MP4 처리 완료.
#
# 30번째 단어의 6번째 영상, 06_30.MP4 처리 시작.
# 30번째 단어의 6번째 영상, 06_30.MP4 처리 완료.
#
# 30번째 단어의 7번째 영상, 07_30.MP4 처리 시작.
# 30번째 단어의 7번째 영상, 07_30.MP4 처리 완료.
#
# 30번째 단어의 8번째 영상, 08_30.MP4 는 존재하지 않습니다. Skipping...
# 30번째 단어의 9번째 영상, 09_30.MP4 처리 시작.
# 30번째 단어의 9번째 영상, 09_30.MP4 처리 완료.
#
# 30번째 단어의 10번째 영상, 10_30.MP4 처리 시작.
# 30번째 단어의 10번째 영상, 10_30.MP4 처리 완료.
#
# 30번째 단어의 11번째 영상, 11_30.MP4 처리 시작.
# 30번째 단어의 11번째 영상, 11_30.MP4 처리 완료.
#
# 30번째 단어의 12번째 영상, 12_30.MP4 처리 시작.
# 30번째 단어의 12번째 영상, 12_30.MP4 처리 완료.
#
# 30번째 단어의 13번째 영상, 13_30.MP4 처리 시작.
# 30번째 단어의 13번째 영상, 13_30.MP4 처리 완료.
#
# 30번째 단어의 14번째 영상, 14_30.MP4 처리 시작.
# 30번째 단어의 14번째 영상, 14_30.MP4 처리 완료.
#
# 30번째 단어의 15번째 영상, 15_30.MP4 처리 시작.
# 30번째 단어의 15번째 영상, 15_30.MP4 처리 완료.
#
# 30번째 단어의 16번째 영상, 16_30.MP4 처리 시작.
# 30번째 단어의 16번째 영상, 16_30.MP4 처리 완료.
#
# 30번째 단어의 17번째 영상, 17_30.MP4 는 존재하지 않습니다. Skipping...
# 30번째 단어의 18번째 영상, 18_30.MP4 는 존재하지 않습니다. Skipping...
# 30번째 단어의 19번째 영상, 19_30.MP4 처리 시작.
# 30번째 단어의 19번째 영상, 19_30.MP4 처리 완료.
#
# 31번째 단어의 0번째 영상, 00_31.MP4 처리 시작.
# 31번째 단어의 0번째 영상, 00_31.MP4 처리 완료.
#
# 31번째 단어의 1번째 영상, 01_31.MP4 처리 시작.
# 31번째 단어의 1번째 영상, 01_31.MP4 처리 완료.
#
# 31번째 단어의 2번째 영상, 02_31.MP4 처리 시작.
# 31번째 단어의 2번째 영상, 02_31.MP4 처리 완료.
#
# 31번째 단어의 3번째 영상, 03_31.MP4 처리 시작.
# 31번째 단어의 3번째 영상, 03_31.MP4 처리 완료.
#
# 31번째 단어의 4번째 영상, 04_31.MP4 처리 시작.
# 31번째 단어의 4번째 영상, 04_31.MP4 처리 완료.
#
# 31번째 단어의 5번째 영상, 05_31.MP4 처리 시작.
# 31번째 단어의 5번째 영상, 05_31.MP4 처리 완료.
#
# 31번째 단어의 6번째 영상, 06_31.MP4 처리 시작.
# 31번째 단어의 6번째 영상, 06_31.MP4 처리 완료.
#
# 31번째 단어의 7번째 영상, 07_31.MP4 처리 시작.
# 31번째 단어의 7번째 영상, 07_31.MP4 처리 완료.
#
# 31번째 단어의 8번째 영상, 08_31.MP4 처리 시작.
# 31번째 단어의 8번째 영상, 08_31.MP4 처리 완료.
#
# 31번째 단어의 9번째 영상, 09_31.MP4 처리 시작.
# 31번째 단어의 9번째 영상, 09_31.MP4 처리 완료.
#
# 31번째 단어의 10번째 영상, 10_31.MP4 처리 시작.
# 31번째 단어의 10번째 영상, 10_31.MP4 처리 완료.
#
# 31번째 단어의 11번째 영상, 11_31.MP4 처리 시작.
# 31번째 단어의 11번째 영상, 11_31.MP4 처리 완료.
#
# 31번째 단어의 12번째 영상, 12_31.MP4 처리 시작.
# 31번째 단어의 12번째 영상, 12_31.MP4 처리 완료.
#
# 31번째 단어의 13번째 영상, 13_31.MP4 처리 시작.
# 31번째 단어의 13번째 영상, 13_31.MP4 처리 완료.
#
# 31번째 단어의 14번째 영상, 14_31.MP4 처리 시작.
# 31번째 단어의 14번째 영상, 14_31.MP4 처리 완료.
#
# 31번째 단어의 15번째 영상, 15_31.MP4 처리 시작.
# 31번째 단어의 15번째 영상, 15_31.MP4 처리 완료.
#
# 31번째 단어의 16번째 영상, 16_31.MP4 처리 시작.
# 31번째 단어의 16번째 영상, 16_31.MP4 처리 완료.
#
# 31번째 단어의 17번째 영상, 17_31.MP4 는 존재하지 않습니다. Skipping...
# 31번째 단어의 18번째 영상, 18_31.MP4 는 존재하지 않습니다. Skipping...
# 31번째 단어의 19번째 영상, 19_31.MP4 처리 시작.
# 31번째 단어의 19번째 영상, 19_31.MP4 처리 완료.
#
# 32번째 단어의 0번째 영상, 00_32.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 32번째 단어의 0번째 영상, 00_32.MP4 처리 완료.
#
# 32번째 단어의 1번째 영상, 01_32.MP4 처리 시작.
# 32번째 단어의 1번째 영상, 01_32.MP4 처리 완료.
#
# 32번째 단어의 2번째 영상, 02_32.MP4 처리 시작.
# 32번째 단어의 2번째 영상, 02_32.MP4 처리 완료.
#
# 32번째 단어의 3번째 영상, 03_32.MP4 처리 시작.
# 32번째 단어의 3번째 영상, 03_32.MP4 처리 완료.
#
# 32번째 단어의 4번째 영상, 04_32.MP4 처리 시작.
# 32번째 단어의 4번째 영상, 04_32.MP4 처리 완료.
#
# 32번째 단어의 5번째 영상, 05_32.MP4 처리 시작.
# 32번째 단어의 5번째 영상, 05_32.MP4 처리 완료.
#
# 32번째 단어의 6번째 영상, 06_32.MP4 는 존재하지 않습니다. Skipping...
# 32번째 단어의 7번째 영상, 07_32.MP4 처리 시작.
# 32번째 단어의 7번째 영상, 07_32.MP4 처리 완료.
#
# 32번째 단어의 8번째 영상, 08_32.MP4 처리 시작.
# 32번째 단어의 8번째 영상, 08_32.MP4 처리 완료.
#
# 32번째 단어의 9번째 영상, 09_32.MP4 는 존재하지 않습니다. Skipping...
# 32번째 단어의 10번째 영상, 10_32.MP4 처리 시작.
# 32번째 단어의 10번째 영상, 10_32.MP4 처리 완료.
#
# 32번째 단어의 11번째 영상, 11_32.MP4 처리 시작.
# 32번째 단어의 11번째 영상, 11_32.MP4 처리 완료.
#
# 32번째 단어의 12번째 영상, 12_32.MP4 처리 시작.
# 32번째 단어의 12번째 영상, 12_32.MP4 처리 완료.
#
# 32번째 단어의 13번째 영상, 13_32.MP4 처리 시작.
# 32번째 단어의 13번째 영상, 13_32.MP4 처리 완료.
#
# 32번째 단어의 14번째 영상, 14_32.MP4 는 존재하지 않습니다. Skipping...
# 32번째 단어의 15번째 영상, 15_32.MP4 처리 시작.
# 32번째 단어의 15번째 영상, 15_32.MP4 처리 완료.
#
# 32번째 단어의 16번째 영상, 16_32.MP4 처리 시작.
# 32번째 단어의 16번째 영상, 16_32.MP4 처리 완료.
#
# 32번째 단어의 17번째 영상, 17_32.MP4 는 존재하지 않습니다. Skipping...
# 32번째 단어의 18번째 영상, 18_32.MP4 는 존재하지 않습니다. Skipping...
# 32번째 단어의 19번째 영상, 19_32.MP4 처리 시작.
# 32번째 단어의 19번째 영상, 19_32.MP4 처리 완료.
#
# 33번째 단어의 0번째 영상, 00_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 1번째 영상, 01_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 2번째 영상, 02_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 3번째 영상, 03_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 4번째 영상, 04_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 5번째 영상, 05_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 6번째 영상, 06_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 7번째 영상, 07_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 8번째 영상, 08_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 9번째 영상, 09_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 10번째 영상, 10_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 11번째 영상, 11_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 12번째 영상, 12_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 13번째 영상, 13_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 14번째 영상, 14_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 15번째 영상, 15_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 16번째 영상, 16_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 17번째 영상, 17_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 18번째 영상, 18_33.MP4 는 존재하지 않습니다. Skipping...
# 33번째 단어의 19번째 영상, 19_33.MP4 는 존재하지 않습니다. Skipping...
# 34번째 단어의 0번째 영상, 00_34.MP4 처리 시작.
# 인식 안됨
# 34번째 단어의 0번째 영상, 00_34.MP4 처리 완료.
#
# 34번째 단어의 1번째 영상, 01_34.MP4 처리 시작.
# 34번째 단어의 1번째 영상, 01_34.MP4 처리 완료.
#
# 34번째 단어의 2번째 영상, 02_34.MP4 처리 시작.
# 34번째 단어의 2번째 영상, 02_34.MP4 처리 완료.
#
# 34번째 단어의 3번째 영상, 03_34.MP4 처리 시작.
# 34번째 단어의 3번째 영상, 03_34.MP4 처리 완료.
#
# 34번째 단어의 4번째 영상, 04_34.MP4 처리 시작.
# 34번째 단어의 4번째 영상, 04_34.MP4 처리 완료.
#
# 34번째 단어의 5번째 영상, 05_34.MP4 처리 시작.
# 34번째 단어의 5번째 영상, 05_34.MP4 처리 완료.
#
# 34번째 단어의 6번째 영상, 06_34.MP4 는 존재하지 않습니다. Skipping...
# 34번째 단어의 7번째 영상, 07_34.MP4 처리 시작.
# 34번째 단어의 7번째 영상, 07_34.MP4 처리 완료.
#
# 34번째 단어의 8번째 영상, 08_34.MP4 처리 시작.
# 34번째 단어의 8번째 영상, 08_34.MP4 처리 완료.
#
# 34번째 단어의 9번째 영상, 09_34.MP4 처리 시작.
# 34번째 단어의 9번째 영상, 09_34.MP4 처리 완료.
#
# 34번째 단어의 10번째 영상, 10_34.MP4 처리 시작.
# 34번째 단어의 10번째 영상, 10_34.MP4 처리 완료.
#
# 34번째 단어의 11번째 영상, 11_34.MP4 처리 시작.
# 34번째 단어의 11번째 영상, 11_34.MP4 처리 완료.
#
# 34번째 단어의 12번째 영상, 12_34.MP4 처리 시작.
# 34번째 단어의 12번째 영상, 12_34.MP4 처리 완료.
#
# 34번째 단어의 13번째 영상, 13_34.MP4 처리 시작.
# 34번째 단어의 13번째 영상, 13_34.MP4 처리 완료.
#
# 34번째 단어의 14번째 영상, 14_34.MP4 처리 시작.
# 34번째 단어의 14번째 영상, 14_34.MP4 처리 완료.
#
# 34번째 단어의 15번째 영상, 15_34.MP4 처리 시작.
# 34번째 단어의 15번째 영상, 15_34.MP4 처리 완료.
#
# 34번째 단어의 16번째 영상, 16_34.MP4 처리 시작.
# 34번째 단어의 16번째 영상, 16_34.MP4 처리 완료.
#
# 34번째 단어의 17번째 영상, 17_34.MP4 는 존재하지 않습니다. Skipping...
# 34번째 단어의 18번째 영상, 18_34.MP4 는 존재하지 않습니다. Skipping...
# 34번째 단어의 19번째 영상, 19_34.MP4 처리 시작.
# 34번째 단어의 19번째 영상, 19_34.MP4 처리 완료.
#
# 35번째 단어의 0번째 영상, 00_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 1번째 영상, 01_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 2번째 영상, 02_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 3번째 영상, 03_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 4번째 영상, 04_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 5번째 영상, 05_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 6번째 영상, 06_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 7번째 영상, 07_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 8번째 영상, 08_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 9번째 영상, 09_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 10번째 영상, 10_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 11번째 영상, 11_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 12번째 영상, 12_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 13번째 영상, 13_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 14번째 영상, 14_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 15번째 영상, 15_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 16번째 영상, 16_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 17번째 영상, 17_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 18번째 영상, 18_35.MP4 는 존재하지 않습니다. Skipping...
# 35번째 단어의 19번째 영상, 19_35.MP4 는 존재하지 않습니다. Skipping...
# 36번째 단어의 0번째 영상, 00_36.MP4 처리 시작.
# 36번째 단어의 0번째 영상, 00_36.MP4 처리 완료.
#
# 36번째 단어의 1번째 영상, 01_36.MP4 처리 시작.
# 36번째 단어의 1번째 영상, 01_36.MP4 처리 완료.
#
# 36번째 단어의 2번째 영상, 02_36.MP4 처리 시작.
# 36번째 단어의 2번째 영상, 02_36.MP4 처리 완료.
#
# 36번째 단어의 3번째 영상, 03_36.MP4 처리 시작.
# 36번째 단어의 3번째 영상, 03_36.MP4 처리 완료.
#
# 36번째 단어의 4번째 영상, 04_36.MP4 처리 시작.
# 36번째 단어의 4번째 영상, 04_36.MP4 처리 완료.
#
# 36번째 단어의 5번째 영상, 05_36.MP4 처리 시작.
# 36번째 단어의 5번째 영상, 05_36.MP4 처리 완료.
#
# 36번째 단어의 6번째 영상, 06_36.MP4 처리 시작.
# 36번째 단어의 6번째 영상, 06_36.MP4 처리 완료.
#
# 36번째 단어의 7번째 영상, 07_36.MP4 처리 시작.
# 36번째 단어의 7번째 영상, 07_36.MP4 처리 완료.
#
# 36번째 단어의 8번째 영상, 08_36.MP4 처리 시작.
# 36번째 단어의 8번째 영상, 08_36.MP4 처리 완료.
#
# 36번째 단어의 9번째 영상, 09_36.MP4 처리 시작.
# 36번째 단어의 9번째 영상, 09_36.MP4 처리 완료.
#
# 36번째 단어의 10번째 영상, 10_36.MP4 처리 시작.
# 36번째 단어의 10번째 영상, 10_36.MP4 처리 완료.
#
# 36번째 단어의 11번째 영상, 11_36.MP4 처리 시작.
# 36번째 단어의 11번째 영상, 11_36.MP4 처리 완료.
#
# 36번째 단어의 12번째 영상, 12_36.MP4 처리 시작.
# 36번째 단어의 12번째 영상, 12_36.MP4 처리 완료.
#
# 36번째 단어의 13번째 영상, 13_36.MP4 처리 시작.
# 36번째 단어의 13번째 영상, 13_36.MP4 처리 완료.
#
# 36번째 단어의 14번째 영상, 14_36.MP4 처리 시작.
# 36번째 단어의 14번째 영상, 14_36.MP4 처리 완료.
#
# 36번째 단어의 15번째 영상, 15_36.MP4 처리 시작.
# 36번째 단어의 15번째 영상, 15_36.MP4 처리 완료.
#
# 36번째 단어의 16번째 영상, 16_36.MP4 처리 시작.
# 36번째 단어의 16번째 영상, 16_36.MP4 처리 완료.
#
# 36번째 단어의 17번째 영상, 17_36.MP4 는 존재하지 않습니다. Skipping...
# 36번째 단어의 18번째 영상, 18_36.MP4 는 존재하지 않습니다. Skipping...
# 36번째 단어의 19번째 영상, 19_36.MP4 처리 시작.
# 36번째 단어의 19번째 영상, 19_36.MP4 처리 완료.
#
# 37번째 단어의 0번째 영상, 00_37.MP4 처리 시작.
# 37번째 단어의 0번째 영상, 00_37.MP4 처리 완료.
#
# 37번째 단어의 1번째 영상, 01_37.MP4 처리 시작.
# 37번째 단어의 1번째 영상, 01_37.MP4 처리 완료.
#
# 37번째 단어의 2번째 영상, 02_37.MP4 처리 시작.
# 37번째 단어의 2번째 영상, 02_37.MP4 처리 완료.
#
# 37번째 단어의 3번째 영상, 03_37.MP4 처리 시작.
# 37번째 단어의 3번째 영상, 03_37.MP4 처리 완료.
#
# 37번째 단어의 4번째 영상, 04_37.MP4 처리 시작.
# 37번째 단어의 4번째 영상, 04_37.MP4 처리 완료.
#
# 37번째 단어의 5번째 영상, 05_37.MP4 처리 시작.
# 37번째 단어의 5번째 영상, 05_37.MP4 처리 완료.
#
# 37번째 단어의 6번째 영상, 06_37.MP4 처리 시작.
# 37번째 단어의 6번째 영상, 06_37.MP4 처리 완료.
#
# 37번째 단어의 7번째 영상, 07_37.MP4 처리 시작.
# 37번째 단어의 7번째 영상, 07_37.MP4 처리 완료.
#
# 37번째 단어의 8번째 영상, 08_37.MP4 처리 시작.
# 37번째 단어의 8번째 영상, 08_37.MP4 처리 완료.
#
# 37번째 단어의 9번째 영상, 09_37.MP4 처리 시작.
# 37번째 단어의 9번째 영상, 09_37.MP4 처리 완료.
#
# 37번째 단어의 10번째 영상, 10_37.MP4 처리 시작.
# 37번째 단어의 10번째 영상, 10_37.MP4 처리 완료.
#
# 37번째 단어의 11번째 영상, 11_37.MP4 처리 시작.
# 37번째 단어의 11번째 영상, 11_37.MP4 처리 완료.
#
# 37번째 단어의 12번째 영상, 12_37.MP4 처리 시작.
# ...
#
# 65번째 단어의 14번째 영상, 14_65.MP4 처리 시작.
# 65번째 단어의 14번째 영상, 14_65.MP4 처리 완료.
#
# 65번째 단어의 15번째 영상, 15_65.MP4 처리 시작.
# 65번째 단어의 15번째 영상, 15_65.MP4 처리 완료.
#
# 65번째 단어의 16번째 영상, 16_65.MP4 처리 시작.
# 65번째 단어의 16번째 영상, 16_65.MP4 처리 완료.
#
# 65번째 단어의 17번째 영상, 17_65.MP4 는 존재하지 않습니다. Skipping...
# 65번째 단어의 18번째 영상, 18_65.MP4 는 존재하지 않습니다. Skipping...
# 65번째 단어의 19번째 영상, 19_65.MP4 처리 시작.
# 65번째 단어의 19번째 영상, 19_65.MP4 처리 완료.
#
# 66번째 단어의 0번째 영상, 00_66.MP4 처리 시작.
# 66번째 단어의 0번째 영상, 00_66.MP4 처리 완료.
#
# 66번째 단어의 1번째 영상, 01_66.MP4 처리 시작.
# 66번째 단어의 1번째 영상, 01_66.MP4 처리 완료.
#
# 66번째 단어의 2번째 영상, 02_66.MP4 처리 시작.
# 66번째 단어의 2번째 영상, 02_66.MP4 처리 완료.
#
# 66번째 단어의 3번째 영상, 03_66.MP4 처리 시작.
# 66번째 단어의 3번째 영상, 03_66.MP4 처리 완료.
#
# 66번째 단어의 4번째 영상, 04_66.MP4 처리 시작.
# 66번째 단어의 4번째 영상, 04_66.MP4 처리 완료.
#
# 66번째 단어의 5번째 영상, 05_66.MP4 는 존재하지 않습니다. Skipping...
# 66번째 단어의 6번째 영상, 06_66.MP4 처리 시작.
# 66번째 단어의 6번째 영상, 06_66.MP4 처리 완료.
#
# 66번째 단어의 7번째 영상, 07_66.MP4 처리 시작.
# 66번째 단어의 7번째 영상, 07_66.MP4 처리 완료.
#
# 66번째 단어의 8번째 영상, 08_66.MP4 처리 시작.
# 66번째 단어의 8번째 영상, 08_66.MP4 처리 완료.
#
# 66번째 단어의 9번째 영상, 09_66.MP4 처리 시작.
# 66번째 단어의 9번째 영상, 09_66.MP4 처리 완료.
#
# 66번째 단어의 10번째 영상, 10_66.MP4 처리 시작.
# 66번째 단어의 10번째 영상, 10_66.MP4 처리 완료.
#
# 66번째 단어의 11번째 영상, 11_66.MP4 처리 시작.
# 66번째 단어의 11번째 영상, 11_66.MP4 처리 완료.
#
# 66번째 단어의 12번째 영상, 12_66.MP4 처리 시작.
# 66번째 단어의 12번째 영상, 12_66.MP4 처리 완료.
#
# 66번째 단어의 13번째 영상, 13_66.MP4 처리 시작.
# 66번째 단어의 13번째 영상, 13_66.MP4 처리 완료.
#
# 66번째 단어의 14번째 영상, 14_66.MP4 처리 시작.
# 66번째 단어의 14번째 영상, 14_66.MP4 처리 완료.
#
# 66번째 단어의 15번째 영상, 15_66.MP4 처리 시작.
# 66번째 단어의 15번째 영상, 15_66.MP4 처리 완료.
#
# 66번째 단어의 16번째 영상, 16_66.MP4 처리 시작.
# 66번째 단어의 16번째 영상, 16_66.MP4 처리 완료.
#
# 66번째 단어의 17번째 영상, 17_66.MP4 는 존재하지 않습니다. Skipping...
# 66번째 단어의 18번째 영상, 18_66.MP4 는 존재하지 않습니다. Skipping...
# 66번째 단어의 19번째 영상, 19_66.MP4 처리 시작.
# 66번째 단어의 19번째 영상, 19_66.MP4 처리 완료.
#
# 67번째 단어의 0번째 영상, 00_67.MP4 처리 시작.
# 67번째 단어의 0번째 영상, 00_67.MP4 처리 완료.
#
# 67번째 단어의 1번째 영상, 01_67.MP4 처리 시작.
# 67번째 단어의 1번째 영상, 01_67.MP4 처리 완료.
#
# 67번째 단어의 2번째 영상, 02_67.MP4 처리 시작.
# 67번째 단어의 2번째 영상, 02_67.MP4 처리 완료.
#
# 67번째 단어의 3번째 영상, 03_67.MP4 처리 시작.
# 67번째 단어의 3번째 영상, 03_67.MP4 처리 완료.
#
# 67번째 단어의 4번째 영상, 04_67.MP4 처리 시작.
# 67번째 단어의 4번째 영상, 04_67.MP4 처리 완료.
#
# 67번째 단어의 5번째 영상, 05_67.MP4 처리 시작.
# 67번째 단어의 5번째 영상, 05_67.MP4 처리 완료.
#
# 67번째 단어의 6번째 영상, 06_67.MP4 처리 시작.
# 67번째 단어의 6번째 영상, 06_67.MP4 처리 완료.
#
# 67번째 단어의 7번째 영상, 07_67.MP4 처리 시작.
# 67번째 단어의 7번째 영상, 07_67.MP4 처리 완료.
#
# 67번째 단어의 8번째 영상, 08_67.MP4 처리 시작.
# 67번째 단어의 8번째 영상, 08_67.MP4 처리 완료.
#
# 67번째 단어의 9번째 영상, 09_67.MP4 처리 시작.
# 67번째 단어의 9번째 영상, 09_67.MP4 처리 완료.
#
# 67번째 단어의 10번째 영상, 10_67.MP4 처리 시작.
# 67번째 단어의 10번째 영상, 10_67.MP4 처리 완료.
#
# 67번째 단어의 11번째 영상, 11_67.MP4 처리 시작.
# 67번째 단어의 11번째 영상, 11_67.MP4 처리 완료.
#
# 67번째 단어의 12번째 영상, 12_67.MP4 처리 시작.
# 67번째 단어의 12번째 영상, 12_67.MP4 처리 완료.
#
# 67번째 단어의 13번째 영상, 13_67.MP4 처리 시작.
# 67번째 단어의 13번째 영상, 13_67.MP4 처리 완료.
#
# 67번째 단어의 14번째 영상, 14_67.MP4 처리 시작.
# 67번째 단어의 14번째 영상, 14_67.MP4 처리 완료.
#
# 67번째 단어의 15번째 영상, 15_67.MP4 처리 시작.
# 67번째 단어의 15번째 영상, 15_67.MP4 처리 완료.
#
# 67번째 단어의 16번째 영상, 16_67.MP4 처리 시작.
# 67번째 단어의 16번째 영상, 16_67.MP4 처리 완료.
#
# 67번째 단어의 17번째 영상, 17_67.MP4 는 존재하지 않습니다. Skipping...
# 67번째 단어의 18번째 영상, 18_67.MP4 는 존재하지 않습니다. Skipping...
# 67번째 단어의 19번째 영상, 19_67.MP4 처리 시작.
# 67번째 단어의 19번째 영상, 19_67.MP4 처리 완료.
#
# 68번째 단어의 0번째 영상, 00_68.MP4 처리 시작.
# 68번째 단어의 0번째 영상, 00_68.MP4 처리 완료.
#
# 68번째 단어의 1번째 영상, 01_68.MP4 처리 시작.
# 68번째 단어의 1번째 영상, 01_68.MP4 처리 완료.
#
# 68번째 단어의 2번째 영상, 02_68.MP4 처리 시작.
# 68번째 단어의 2번째 영상, 02_68.MP4 처리 완료.
#
# 68번째 단어의 3번째 영상, 03_68.MP4 처리 시작.
# 68번째 단어의 3번째 영상, 03_68.MP4 처리 완료.
#
# 68번째 단어의 4번째 영상, 04_68.MP4 처리 시작.
# 68번째 단어의 4번째 영상, 04_68.MP4 처리 완료.
#
# 68번째 단어의 5번째 영상, 05_68.MP4 는 존재하지 않습니다. Skipping...
# 68번째 단어의 6번째 영상, 06_68.MP4 처리 시작.
# 68번째 단어의 6번째 영상, 06_68.MP4 처리 완료.
#
# 68번째 단어의 7번째 영상, 07_68.MP4 처리 시작.
# 68번째 단어의 7번째 영상, 07_68.MP4 처리 완료.
#
# 68번째 단어의 8번째 영상, 08_68.MP4 처리 시작.
# 68번째 단어의 8번째 영상, 08_68.MP4 처리 완료.
#
# 68번째 단어의 9번째 영상, 09_68.MP4 처리 시작.
# 68번째 단어의 9번째 영상, 09_68.MP4 처리 완료.
#
# 68번째 단어의 10번째 영상, 10_68.MP4 처리 시작.
# 68번째 단어의 10번째 영상, 10_68.MP4 처리 완료.
#
# 68번째 단어의 11번째 영상, 11_68.MP4 처리 시작.
# 68번째 단어의 11번째 영상, 11_68.MP4 처리 완료.
#
# 68번째 단어의 12번째 영상, 12_68.MP4 처리 시작.
# 68번째 단어의 12번째 영상, 12_68.MP4 처리 완료.
#
# 68번째 단어의 13번째 영상, 13_68.MP4 처리 시작.
# 68번째 단어의 13번째 영상, 13_68.MP4 처리 완료.
#
# 68번째 단어의 14번째 영상, 14_68.MP4 처리 시작.
# 68번째 단어의 14번째 영상, 14_68.MP4 처리 완료.
#
# 68번째 단어의 15번째 영상, 15_68.MP4 처리 시작.
# 68번째 단어의 15번째 영상, 15_68.MP4 처리 완료.
#
# 68번째 단어의 16번째 영상, 16_68.MP4 처리 시작.
# 68번째 단어의 16번째 영상, 16_68.MP4 처리 완료.
#
# 68번째 단어의 17번째 영상, 17_68.MP4 는 존재하지 않습니다. Skipping...
# 68번째 단어의 18번째 영상, 18_68.MP4 는 존재하지 않습니다. Skipping...
# 68번째 단어의 19번째 영상, 19_68.MP4 처리 시작.
# 68번째 단어의 19번째 영상, 19_68.MP4 처리 완료.
#
# 69번째 단어의 0번째 영상, 00_69.MP4 처리 시작.
# 69번째 단어의 0번째 영상, 00_69.MP4 처리 완료.
#
# 69번째 단어의 1번째 영상, 01_69.MP4 처리 시작.
# 69번째 단어의 1번째 영상, 01_69.MP4 처리 완료.
#
# 69번째 단어의 2번째 영상, 02_69.MP4 처리 시작.
# 69번째 단어의 2번째 영상, 02_69.MP4 처리 완료.
#
# 69번째 단어의 3번째 영상, 03_69.MP4 처리 시작.
# 69번째 단어의 3번째 영상, 03_69.MP4 처리 완료.
#
# 69번째 단어의 4번째 영상, 04_69.MP4 처리 시작.
# 69번째 단어의 4번째 영상, 04_69.MP4 처리 완료.
#
# 69번째 단어의 5번째 영상, 05_69.MP4 처리 시작.
# 69번째 단어의 5번째 영상, 05_69.MP4 처리 완료.
#
# 69번째 단어의 6번째 영상, 06_69.MP4 처리 시작.
# 69번째 단어의 6번째 영상, 06_69.MP4 처리 완료.
#
# 69번째 단어의 7번째 영상, 07_69.MP4 처리 시작.
# 69번째 단어의 7번째 영상, 07_69.MP4 처리 완료.
#
# 69번째 단어의 8번째 영상, 08_69.MP4 처리 시작.
# 69번째 단어의 8번째 영상, 08_69.MP4 처리 완료.
#
# 69번째 단어의 9번째 영상, 09_69.MP4 처리 시작.
# 69번째 단어의 9번째 영상, 09_69.MP4 처리 완료.
#
# 69번째 단어의 10번째 영상, 10_69.MP4 처리 시작.
# 69번째 단어의 10번째 영상, 10_69.MP4 처리 완료.
#
# 69번째 단어의 11번째 영상, 11_69.MP4 처리 시작.
# 69번째 단어의 11번째 영상, 11_69.MP4 처리 완료.
#
# 69번째 단어의 12번째 영상, 12_69.MP4 처리 시작.
# 69번째 단어의 12번째 영상, 12_69.MP4 처리 완료.
#
# 69번째 단어의 13번째 영상, 13_69.MP4 처리 시작.
# 69번째 단어의 13번째 영상, 13_69.MP4 처리 완료.
#
# 69번째 단어의 14번째 영상, 14_69.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 69번째 단어의 14번째 영상, 14_69.MP4 처리 완료.
#
# 69번째 단어의 15번째 영상, 15_69.MP4 처리 시작.
# 69번째 단어의 15번째 영상, 15_69.MP4 처리 완료.
#
# 69번째 단어의 16번째 영상, 16_69.MP4 처리 시작.
# 69번째 단어의 16번째 영상, 16_69.MP4 처리 완료.
#
# 69번째 단어의 17번째 영상, 17_69.MP4 는 존재하지 않습니다. Skipping...
# 69번째 단어의 18번째 영상, 18_69.MP4 는 존재하지 않습니다. Skipping...
# 69번째 단어의 19번째 영상, 19_69.MP4 처리 시작.
# 69번째 단어의 19번째 영상, 19_69.MP4 처리 완료.
#
# 70번째 단어의 0번째 영상, 00_70.MP4 처리 시작.
# 70번째 단어의 0번째 영상, 00_70.MP4 처리 완료.
#
# 70번째 단어의 1번째 영상, 01_70.MP4 처리 시작.
# 70번째 단어의 1번째 영상, 01_70.MP4 처리 완료.
#
# 70번째 단어의 2번째 영상, 02_70.MP4 처리 시작.
# 70번째 단어의 2번째 영상, 02_70.MP4 처리 완료.
#
# 70번째 단어의 3번째 영상, 03_70.MP4 처리 시작.
# 70번째 단어의 3번째 영상, 03_70.MP4 처리 완료.
#
# 70번째 단어의 4번째 영상, 04_70.MP4 는 존재하지 않습니다. Skipping...
# 70번째 단어의 5번째 영상, 05_70.MP4 는 존재하지 않습니다. Skipping...
# 70번째 단어의 6번째 영상, 06_70.MP4 처리 시작.
# 70번째 단어의 6번째 영상, 06_70.MP4 처리 완료.
#
# 70번째 단어의 7번째 영상, 07_70.MP4 처리 시작.
# 70번째 단어의 7번째 영상, 07_70.MP4 처리 완료.
#
# 70번째 단어의 8번째 영상, 08_70.MP4 처리 시작.
# 70번째 단어의 8번째 영상, 08_70.MP4 처리 완료.
#
# 70번째 단어의 9번째 영상, 09_70.MP4 처리 시작.
# 70번째 단어의 9번째 영상, 09_70.MP4 처리 완료.
#
# 70번째 단어의 10번째 영상, 10_70.MP4 처리 시작.
# 70번째 단어의 10번째 영상, 10_70.MP4 처리 완료.
#
# 70번째 단어의 11번째 영상, 11_70.MP4 처리 시작.
# 70번째 단어의 11번째 영상, 11_70.MP4 처리 완료.
#
# 70번째 단어의 12번째 영상, 12_70.MP4 처리 시작.
# 70번째 단어의 12번째 영상, 12_70.MP4 처리 완료.
#
# 70번째 단어의 13번째 영상, 13_70.MP4 처리 시작.
# 70번째 단어의 13번째 영상, 13_70.MP4 처리 완료.
#
# 70번째 단어의 14번째 영상, 14_70.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 70번째 단어의 14번째 영상, 14_70.MP4 처리 완료.
#
# 70번째 단어의 15번째 영상, 15_70.MP4 처리 시작.
# 70번째 단어의 15번째 영상, 15_70.MP4 처리 완료.
#
# 70번째 단어의 16번째 영상, 16_70.MP4 처리 시작.
# 70번째 단어의 16번째 영상, 16_70.MP4 처리 완료.
#
# 70번째 단어의 17번째 영상, 17_70.MP4 는 존재하지 않습니다. Skipping...
# 70번째 단어의 18번째 영상, 18_70.MP4 는 존재하지 않습니다. Skipping...
# 70번째 단어의 19번째 영상, 19_70.MP4 처리 시작.
# 70번째 단어의 19번째 영상, 19_70.MP4 처리 완료.
#
# 71번째 단어의 0번째 영상, 00_71.MP4 처리 시작.
# 71번째 단어의 0번째 영상, 00_71.MP4 처리 완료.
#
# 71번째 단어의 1번째 영상, 01_71.MP4 는 존재하지 않습니다. Skipping...
# 71번째 단어의 2번째 영상, 02_71.MP4 는 존재하지 않습니다. Skipping...
# 71번째 단어의 3번째 영상, 03_71.MP4 처리 시작.
# 71번째 단어의 3번째 영상, 03_71.MP4 처리 완료.
#
# 71번째 단어의 4번째 영상, 04_71.MP4 는 존재하지 않습니다. Skipping...
# 71번째 단어의 5번째 영상, 05_71.MP4 는 존재하지 않습니다. Skipping...
# 71번째 단어의 6번째 영상, 06_71.MP4 는 존재하지 않습니다. Skipping...
# 71번째 단어의 7번째 영상, 07_71.MP4 처리 시작.
# 71번째 단어의 7번째 영상, 07_71.MP4 처리 완료.
#
# 71번째 단어의 8번째 영상, 08_71.MP4 처리 시작.
# 71번째 단어의 8번째 영상, 08_71.MP4 처리 완료.
#
# 71번째 단어의 9번째 영상, 09_71.MP4 처리 시작.
# 71번째 단어의 9번째 영상, 09_71.MP4 처리 완료.
#
# 71번째 단어의 10번째 영상, 10_71.MP4 처리 시작.
# 71번째 단어의 10번째 영상, 10_71.MP4 처리 완료.
#
# 71번째 단어의 11번째 영상, 11_71.MP4 처리 시작.
# 71번째 단어의 11번째 영상, 11_71.MP4 처리 완료.
#
# 71번째 단어의 12번째 영상, 12_71.MP4 처리 시작.
# 71번째 단어의 12번째 영상, 12_71.MP4 처리 완료.
#
# 71번째 단어의 13번째 영상, 13_71.MP4 처리 시작.
# 71번째 단어의 13번째 영상, 13_71.MP4 처리 완료.
#
# 71번째 단어의 14번째 영상, 14_71.MP4 처리 시작.
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 인식 안됨
# 71번째 단어의 14번째 영상, 14_71.MP4 처리 완료.
#
# 71번째 단어의 15번째 영상, 15_71.MP4 처리 시작.
# 71번째 단어의 15번째 영상, 15_71.MP4 처리 완료.
#
# 71번째 단어의 16번째 영상, 16_71.MP4 는 존재하지 않습니다. Skipping...
# 71번째 단어의 17번째 영상, 17_71.MP4 는 존재하지 않습니다. Skipping...
# 71번째 단어의 18번째 영상, 18_71.MP4 는 존재하지 않습니다. Skipping...
# 71번째 단어의 19번째 영상, 19_71.MP4 처리 시작.
# 71번째 단어의 19번째 영상, 19_71.MP4 처리 완료.
#
# 72번째 단어의 0번째 영상, 00_72.MP4 처리 시작.
# 72번째 단어의 0번째 영상, 00_72.MP4 처리 완료.
#
# 72번째 단어의 1번째 영상, 01_72.MP4 처리 시작.
# 72번째 단어의 1번째 영상, 01_72.MP4 처리 완료.
#
# 72번째 단어의 2번째 영상, 02_72.MP4 처리 시작.
# 72번째 단어의 2번째 영상, 02_72.MP4 처리 완료.
#
# 72번째 단어의 3번째 영상, 03_72.MP4 처리 시작.
# 72번째 단어의 3번째 영상, 03_72.MP4 처리 완료.
#
# 72번째 단어의 4번째 영상, 04_72.MP4 는 존재하지 않습니다. Skipping...
# 72번째 단어의 5번째 영상, 05_72.MP4 처리 시작.
# 72번째 단어의 5번째 영상, 05_72.MP4 처리 완료.
#
# 72번째 단어의 6번째 영상, 06_72.MP4 처리 시작.
# 72번째 단어의 6번째 영상, 06_72.MP4 처리 완료.
#
# 72번째 단어의 7번째 영상, 07_72.MP4 처리 시작.
# 72번째 단어의 7번째 영상, 07_72.MP4 처리 완료.
#
# 72번째 단어의 8번째 영상, 08_72.MP4 처리 시작.
# 72번째 단어의 8번째 영상, 08_72.MP4 처리 완료.
#
# 72번째 단어의 9번째 영상, 09_72.MP4 처리 시작.
# 72번째 단어의 9번째 영상, 09_72.MP4 처리 완료.
#
# 72번째 단어의 10번째 영상, 10_72.MP4 처리 시작.
# 72번째 단어의 10번째 영상, 10_72.MP4 처리 완료.
#
# 72번째 단어의 11번째 영상, 11_72.MP4 처리 시작.
# 72번째 단어의 11번째 영상, 11_72.MP4 처리 완료.
#
# 72번째 단어의 12번째 영상, 12_72.MP4 처리 시작.
# 72번째 단어의 12번째 영상, 12_72.MP4 처리 완료.
#
# 72번째 단어의 13번째 영상, 13_72.MP4 처리 시작.
# 72번째 단어의 13번째 영상, 13_72.MP4 처리 완료.
#
# 72번째 단어의 14번째 영상, 14_72.MP4 처리 시작.
# 72번째 단어의 14번째 영상, 14_72.MP4 처리 완료.
#
# 72번째 단어의 15번째 영상, 15_72.MP4 처리 시작.
# 72번째 단어의 15번째 영상, 15_72.MP4 처리 완료.
#
# 72번째 단어의 16번째 영상, 16_72.MP4 처리 시작.
# 72번째 단어의 16번째 영상, 16_72.MP4 처리 완료.
#
# 72번째 단어의 17번째 영상, 17_72.MP4 는 존재하지 않습니다. Skipping...
# 72번째 단어의 18번째 영상, 18_72.MP4 는 존재하지 않습니다. Skipping...
# 72번째 단어의 19번째 영상, 19_72.MP4 처리 시작.
# 72번째 단어의 19번째 영상, 19_72.MP4 처리 완료.
#
# 73번째 단어의 0번째 영상, 00_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 1번째 영상, 01_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 2번째 영상, 02_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 3번째 영상, 03_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 4번째 영상, 04_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 5번째 영상, 05_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 6번째 영상, 06_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 7번째 영상, 07_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 8번째 영상, 08_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 9번째 영상, 09_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 10번째 영상, 10_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 11번째 영상, 11_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 12번째 영상, 12_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 13번째 영상, 13_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 14번째 영상, 14_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 15번째 영상, 15_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 16번째 영상, 16_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 17번째 영상, 17_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 18번째 영상, 18_73.MP4 는 존재하지 않습니다. Skipping...
# 73번째 단어의 19번째 영상, 19_73.MP4 는 존재하지 않습니다. Skipping...
# 74번째 단어의 0번째 영상, 00_74.MP4 처리 시작.
# 74번째 단어의 0번째 영상, 00_74.MP4 처리 완료.
#
# 74번째 단어의 1번째 영상, 01_74.MP4 처리 시작.
# 74번째 단어의 1번째 영상, 01_74.MP4 처리 완료.
#
# 74번째 단어의 2번째 영상, 02_74.MP4 처리 시작.
# 74번째 단어의 2번째 영상, 02_74.MP4 처리 완료.
#
# 74번째 단어의 3번째 영상, 03_74.MP4 처리 시작.
# 74번째 단어의 3번째 영상, 03_74.MP4 처리 완료.
#
# 74번째 단어의 4번째 영상, 04_74.MP4 처리 시작.
# 74번째 단어의 4번째 영상, 04_74.MP4 처리 완료.
#
# 74번째 단어의 5번째 영상, 05_74.MP4 처리 시작.
# 74번째 단어의 5번째 영상, 05_74.MP4 처리 완료.
#
# 74번째 단어의 6번째 영상, 06_74.MP4 처리 시작.
# 74번째 단어의 6번째 영상, 06_74.MP4 처리 완료.
#
# 74번째 단어의 7번째 영상, 07_74.MP4 처리 시작.
# 74번째 단어의 7번째 영상, 07_74.MP4 처리 완료.
#
# 74번째 단어의 8번째 영상, 08_74.MP4 처리 시작.
# 74번째 단어의 8번째 영상, 08_74.MP4 처리 완료.
#
# 74번째 단어의 9번째 영상, 09_74.MP4 처리 시작.
# 74번째 단어의 9번째 영상, 09_74.MP4 처리 완료.
#
# 74번째 단어의 10번째 영상, 10_74.MP4 처리 시작.
# 74번째 단어의 10번째 영상, 10_74.MP4 처리 완료.
#
# 74번째 단어의 11번째 영상, 11_74.MP4 처리 시작.
# 74번째 단어의 11번째 영상, 11_74.MP4 처리 완료.
#
# 74번째 단어의 12번째 영상, 12_74.MP4 처리 시작.
# 74번째 단어의 12번째 영상, 12_74.MP4 처리 완료.
#
# 74번째 단어의 13번째 영상, 13_74.MP4 처리 시작.
# 74번째 단어의 13번째 영상, 13_74.MP4 처리 완료.
#
# 74번째 단어의 14번째 영상, 14_74.MP4 처리 시작.
# 74번째 단어의 14번째 영상, 14_74.MP4 처리 완료.
#
# 74번째 단어의 15번째 영상, 15_74.MP4 처리 시작.
# 74번째 단어의 15번째 영상, 15_74.MP4 처리 완료.
#
# 74번째 단어의 16번째 영상, 16_74.MP4 처리 시작.
# 74번째 단어의 16번째 영상, 16_74.MP4 처리 완료.
#
# 74번째 단어의 17번째 영상, 17_74.MP4 는 존재하지 않습니다. Skipping...
# 74번째 단어의 18번째 영상, 18_74.MP4 는 존재하지 않습니다. Skipping...
# 74번째 단어의 19번째 영상, 19_74.MP4 처리 시작.
# 74번째 단어의 19번째 영상, 19_74.MP4 처리 완료.
#
# 75번째 단어의 0번째 영상, 00_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 1번째 영상, 01_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 2번째 영상, 02_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 3번째 영상, 03_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 4번째 영상, 04_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 5번째 영상, 05_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 6번째 영상, 06_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 7번째 영상, 07_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 8번째 영상, 08_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 9번째 영상, 09_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 10번째 영상, 10_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 11번째 영상, 11_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 12번째 영상, 12_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 13번째 영상, 13_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 14번째 영상, 14_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 15번째 영상, 15_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 16번째 영상, 16_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 17번째 영상, 17_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 18번째 영상, 18_75.MP4 는 존재하지 않습니다. Skipping...
# 75번째 단어의 19번째 영상, 19_75.MP4 는 존재하지 않습니다. Skipping...
# 76번째 단어의 0번째 영상, 00_76.MP4 처리 시작.
# 76번째 단어의 0번째 영상, 00_76.MP4 처리 완료.
#
# 76번째 단어의 1번째 영상, 01_76.MP4 처리 시작.
# 76번째 단어의 1번째 영상, 01_76.MP4 처리 완료.
#
# 76번째 단어의 2번째 영상, 02_76.MP4 처리 시작.
# 76번째 단어의 2번째 영상, 02_76.MP4 처리 완료.
#
# 76번째 단어의 3번째 영상, 03_76.MP4 처리 시작.
# 76번째 단어의 3번째 영상, 03_76.MP4 처리 완료.
#
# 76번째 단어의 4번째 영상, 04_76.MP4 처리 시작.
# 76번째 단어의 4번째 영상, 04_76.MP4 처리 완료.
#
# 76번째 단어의 5번째 영상, 05_76.MP4 처리 시작.
# 76번째 단어의 5번째 영상, 05_76.MP4 처리 완료.
#
# 76번째 단어의 6번째 영상, 06_76.MP4 처리 시작.
# 76번째 단어의 6번째 영상, 06_76.MP4 처리 완료.
#
# 76번째 단어의 7번째 영상, 07_76.MP4 처리 시작.
# 76번째 단어의 7번째 영상, 07_76.MP4 처리 완료.
#
# 76번째 단어의 8번째 영상, 08_76.MP4 처리 시작.
# 76번째 단어의 8번째 영상, 08_76.MP4 처리 완료.
#
# 76번째 단어의 9번째 영상, 09_76.MP4 처리 시작.
# 76번째 단어의 9번째 영상, 09_76.MP4 처리 완료.
#
# 76번째 단어의 10번째 영상, 10_76.MP4 처리 시작.
# 76번째 단어의 10번째 영상, 10_76.MP4 처리 완료.
#
# 76번째 단어의 11번째 영상, 11_76.MP4 처리 시작.
# 76번째 단어의 11번째 영상, 11_76.MP4 처리 완료.
#
# 76번째 단어의 12번째 영상, 12_76.MP4 처리 시작.
# 76번째 단어의 12번째 영상, 12_76.MP4 처리 완료.
#
# 76번째 단어의 13번째 영상, 13_76.MP4 처리 시작.
# 76번째 단어의 13번째 영상, 13_76.MP4 처리 완료.
#
# 76번째 단어의 14번째 영상, 14_76.MP4 처리 시작.
# 76번째 단어의 14번째 영상, 14_76.MP4 처리 완료.
#
# 76번째 단어의 15번째 영상, 15_76.MP4 처리 시작.
# 76번째 단어의 15번째 영상, 15_76.MP4 처리 완료.
#
# 76번째 단어의 16번째 영상, 16_76.MP4 처리 시작.
# 76번째 단어의 16번째 영상, 16_76.MP4 처리 완료.
#
# 76번째 단어의 17번째 영상, 17_76.MP4 는 존재하지 않습니다. Skipping...
# 76번째 단어의 18번째 영상, 18_76.MP4 는 존재하지 않습니다. Skipping...
# 76번째 단어의 19번째 영상, 19_76.MP4 처리 시작.
# 76번째 단어의 19번째 영상, 19_76.MP4 처리 완료.
#
# 77번째 단어의 0번째 영상, 00_77.MP4 처리 시작.
# 77번째 단어의 0번째 영상, 00_77.MP4 처리 완료.
#
# 77번째 단어의 1번째 영상, 01_77.MP4 처리 시작.
# 77번째 단어의 1번째 영상, 01_77.MP4 처리 완료.
#
# 77번째 단어의 2번째 영상, 02_77.MP4 처리 시작.
# 77번째 단어의 2번째 영상, 02_77.MP4 처리 완료.
#
# 77번째 단어의 3번째 영상, 03_77.MP4 처리 시작.
# 77번째 단어의 3번째 영상, 03_77.MP4 처리 완료.
#
# 77번째 단어의 4번째 영상, 04_77.MP4 처리 시작.
# 77번째 단어의 4번째 영상, 04_77.MP4 처리 완료.
#
# 77번째 단어의 5번째 영상, 05_77.MP4 처리 시작.
# 77번째 단어의 5번째 영상, 05_77.MP4 처리 완료.
#
# 77번째 단어의 6번째 영상, 06_77.MP4 처리 시작.
# 77번째 단어의 6번째 영상, 06_77.MP4 처리 완료.
#
# 77번째 단어의 7번째 영상, 07_77.MP4 처리 시작.
# 77번째 단어의 7번째 영상, 07_77.MP4 처리 완료.
#
# 77번째 단어의 8번째 영상, 08_77.MP4 처리 시작.
# 77번째 단어의 8번째 영상, 08_77.MP4 처리 완료.
#
# 77번째 단어의 9번째 영상, 09_77.MP4 처리 시작.
# 77번째 단어의 9번째 영상, 09_77.MP4 처리 완료.
#
# 77번째 단어의 10번째 영상, 10_77.MP4 처리 시작.
# 77번째 단어의 10번째 영상, 10_77.MP4 처리 완료.
#
# 77번째 단어의 11번째 영상, 11_77.MP4 처리 시작.
# 77번째 단어의 11번째 영상, 11_77.MP4 처리 완료.
#
# 77번째 단어의 12번째 영상, 12_77.MP4 처리 시작.
# 77번째 단어의 12번째 영상, 12_77.MP4 처리 완료.
#
# 77번째 단어의 13번째 영상, 13_77.MP4 처리 시작.
# 77번째 단어의 13번째 영상, 13_77.MP4 처리 완료.
#
# 77번째 단어의 14번째 영상, 14_77.MP4 처리 시작.
# 77번째 단어의 14번째 영상, 14_77.MP4 처리 완료.
#
# 77번째 단어의 15번째 영상, 15_77.MP4 처리 시작.
# 77번째 단어의 15번째 영상, 15_77.MP4 처리 완료.
#
# 77번째 단어의 16번째 영상, 16_77.MP4 처리 시작.
# 77번째 단어의 16번째 영상, 16_77.MP4 처리 완료.
#
# 77번째 단어의 17번째 영상, 17_77.MP4 는 존재하지 않습니다. Skipping...
# 77번째 단어의 18번째 영상, 18_77.MP4 는 존재하지 않습니다. Skipping...
# 77번째 단어의 19번째 영상, 19_77.MP4 처리 시작.
# 77번째 단어의 19번째 영상, 19_77.MP4 처리 완료.
